# %% [markdown]
# # DSE Multi-Company LSTM Trainer (1, 3, 7-day forecasts)
#
# This notebook trains **separate LSTM models per company/scrip** from a single CSV of OHLCV data,
# and for **three forecast horizons**: `n_ahead = 1, 3, 7`.
#
# - Input CSV layout (example):
#   ```
#   Date,Scrip,Open,High,Low,Close,Volume
#   2000-01-01,ACI,12.67,13.77,12.67,13.63,19850
#   2000-01-01,ALLTEX,4.7,4.75,4.7,4.7,17500
#   ```
# - Output: per `Scrip` directory under `models/`:
#   - `lstm_{SCRIP}_seq{SEQ_LEN}_nahead{N}.keras` (Keras v3 single-file model)
#   - `scaler_{SCRIP}.bin` (MinMaxScaler fit on training data of that Scrip)
#   - optional predictions/metrics files
#
# **Notes & choices**
# - Uses **MinMaxScaler** fit on the **training split only** to avoid data leakage; applied to test/validation and future inputs via `.transform()`.
# - Univariate LSTM on `Close` by default (simplest & common baseline). You can switch to multivariate by changing `FEATURE_COLS`.
# - Three distinct models per scrip (for 1, 3, and 7-day horizons). One scaler per scrip.
# - Robust to short histories (skips scrips that don't have enough rows).

# %% [markdown]
# ## 0) (Optional) Install dependencies
#
# Run this **only if you get import errors**. Pin versions as needed for your environment.

# %%
# If needed, uncomment and run:
# %pip install -q --upgrade pip
# %pip install -q numpy pandas scikit-learn tensorflow matplotlib joblib

# %% [markdown]
# ## 1) Imports & Reproducibility

# %%
import os
import json
import math
import joblib
import numpy as np
import pandas as pd

from datetime import timedelta

# TensorFlow / Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Reproducibility
def set_global_seed(seed: int = 42):
    import random
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

set_global_seed(42)

print(tf.__version__)
# Out:
# 2025-10-07 23:42:15.433574: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.20.0

# %% [markdown]
# ## 2) Configuration
#
# - `CSV_PATH`: path to your **single** CSV with all companies.
# - `SCRIP_COLUMN`, `DATE_COLUMN`: column names in your CSV.
# - `TARGET_COLUMN`: which column to forecast (default `Close`).
# - `SEQ_LEN`: lookback window length (e.g., 60).
# - `HORIZONS`: list of forecast horizons to train for (here: `[1, 3, 7]`).
#
# Models and scalers are saved under `SAVE_DIR/models/{Scrip}/`.
# Optionally, predictions/metrics go to `SAVE_DIR/predictions/` and `SAVE_DIR/metrics/`.

# %%
# === Required: set your CSV path here ===
CSV_PATH = "./dataset/merged_stock_data.csv"  # <- CHANGE THIS to your dataset path

# === Columns ===
DATE_COLUMN = "Date"
SCRIP_COLUMN = "Scrip"
TARGET_COLUMN = "Close"   # forecasting Close

# Optional multivariate: include more features here.
# For baseline univariate LSTM on Close only, leave as ["Close"].
FEATURE_COLS = ["Close"]

# === Sequence & horizons ===
SEQ_LEN = 60
HORIZONS = [1, 3, 7]

# === Splits ===
TRAIN_RATIO = 0.8  # remaining used for testing; validation handled via validation_split in .fit

# === Training hyperparams ===
MAX_EPOCHS = 100
BATCH_SIZE = 64
LEARNING_RATE = 1e-3
PATIENCE = 10  # early stopping
VAL_SPLIT = 0.2

# === Save locations ===
SAVE_DIR = "./artifacts"  # root
MODELS_DIR = os.path.join(SAVE_DIR, "models")
PREDS_DIR = os.path.join(SAVE_DIR, "predictions")
METRICS_DIR = os.path.join(SAVE_DIR, "metrics")

os.makedirs(MODELS_DIR, exist_ok=True)
os.makedirs(PREDS_DIR, exist_ok=True)
os.makedirs(METRICS_DIR, exist_ok=True)

print("Saving to:", os.path.abspath(SAVE_DIR))
# Out:
# Saving to: /mnt/Work/projects/stock_cast/predictor/artifacts

# %% [markdown]
# ## 3) Data Loading & Utilities
# - Reads CSV, parses dates, sorts by `Date`.
# - Lists all unique `Scrip` values.
# - For each scrip:
#   - Splits by date into **train/test** (no shuffling).
#   - Fits `MinMaxScaler` on **train** only (to avoid leakage).
#   - Builds sliding windows of shape `(samples, SEQ_LEN, n_features)` with targets of shape `(samples, N_AHEAD)`.

# %%
from sklearn.preprocessing import MinMaxScaler
from typing import Tuple, Dict, Any

def read_all_data(csv_path: str) -> pd.DataFrame:
    df = pd.read_csv(csv_path)
    assert DATE_COLUMN in df.columns, f"Missing column: {DATE_COLUMN}"
    assert SCRIP_COLUMN in df.columns, f"Missing column: {SCRIP_COLUMN}"
    assert TARGET_COLUMN in df.columns, f"Missing column: {TARGET_COLUMN}"
    # Ensure Date type and sorting
    df[DATE_COLUMN] = pd.to_datetime(df[DATE_COLUMN])
    df = df.sort_values([SCRIP_COLUMN, DATE_COLUMN]).reset_index(drop=True)
    return df

def get_scrips(df: pd.DataFrame) -> np.ndarray:
    return df[SCRIP_COLUMN].dropna().unique()

def split_train_test(values_len: int, train_ratio: float) -> Tuple[int, int]:
    train_end = int(values_len * train_ratio)
    test_start = train_end
    return train_end, test_start

def fit_scaler_on_train(train_df: pd.DataFrame) -> MinMaxScaler:
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaler.fit(train_df[FEATURE_COLS].values)
    return scaler

def scale_df(df: pd.DataFrame, scaler: MinMaxScaler) -> np.ndarray:
    return scaler.transform(df[FEATURE_COLS].values)

def build_sequences(values: np.ndarray, seq_len: int, n_ahead: int) -> Tuple[np.ndarray, np.ndarray]:
    """
    values: scaled array shape (T, n_features). We'll predict TARGET_COLUMN but here we assume FEATURE_COLS includes it.
    For univariate, n_features=1 and both X and y come from the same array.
    """
    X, y = [], []
    T = len(values)
    for i in range(T - seq_len - n_ahead + 1):
        window = values[i:i+seq_len]
        target = values[i+seq_len:i+seq_len+n_ahead, 0]  # use first column as target (Close)
        X.append(window)
        y.append(target)
    return np.array(X), np.array(y)

def prepare_scrip_data(scrip_df: pd.DataFrame, seq_len: int, n_ahead: int, train_ratio: float) -> Dict[str, Any]:
    # split into train/test by date order
    n = len(scrip_df)
    train_end, test_start = split_train_test(n, train_ratio=train_ratio)
    train_df = scrip_df.iloc[:train_end].copy()
    test_df  = scrip_df.iloc[test_start:].copy()

    # fit scaler on TRAIN only
    scaler = fit_scaler_on_train(train_df)

    # transform
    train_scaled = scale_df(train_df, scaler)
    test_scaled  = scale_df(test_df, scaler)

    # build sequences separately to avoid leakage across the split
    X_train, y_train = build_sequences(train_scaled, seq_len, n_ahead)
    X_test, y_test   = build_sequences(test_scaled, seq_len, n_ahead)

    return {
        "scaler": scaler,
        "train_df": train_df,
        "test_df": test_df,
        "X_train": X_train, "y_train": y_train,
        "X_test": X_test, "y_test": y_test,
    }

# %% [markdown]
# ## 4) Model Builder
#
# Simple, sturdy baseline:
# - 2 stacked LSTM layers with dropout
# - Dense output of size `N_AHEAD`
# - Adam optimizer
# - EarlyStopping + ReduceLROnPlateau

# %%
def build_lstm_model(input_shape, n_ahead: int, lr: float = LEARNING_RATE) -> keras.Model:
    model = keras.Sequential([
        layers.Input(shape=input_shape),
        layers.LSTM(64, return_sequences=True),
        layers.Dropout(0.2),
        layers.LSTM(32),
        layers.Dropout(0.2),
        layers.Dense(n_ahead)  # outputs N_AHEAD values
    ])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=lr),
                  loss="mse",
                  metrics=["mae"])
    return model

def get_callbacks():
    es = keras.callbacks.EarlyStopping(monitor="val_loss", patience=PATIENCE, restore_best_weights=True)
    rlrop = keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=max(3, PATIENCE//2), min_lr=1e-5)
    return [es, rlrop]

# %% [markdown]
# ## 5) Training & Saving Helpers
#
# - Trains a model for a single `(Scrip, N_AHEAD)` pair.
# - Saves the Keras model and the scaler (only once per Scrip).
# - Evaluates on test set (RMSE, MAPE) and saves metrics & optional predictions.

# %%
from math import sqrt

def rmse(y_true, y_pred):
    return sqrt(np.mean((y_true - y_pred) ** 2))

def mape(y_true, y_pred, eps=1e-8):
    return np.mean(np.abs((y_true - y_pred) / np.maximum(np.abs(y_true), eps))) * 100.0

def inverse_transform_1d(arr_1d, scaler: MinMaxScaler) -> np.ndarray:
    """Inverse transform a 1D array that represents the TARGET_COLUMN only."""
    return scaler.inverse_transform(np.array(arr_1d).reshape(-1, 1)).ravel()

def train_one_horizon(scrip: str, scrip_df: pd.DataFrame, n_ahead: int, save_root: str) -> Dict[str, Any]:
    # prepare data
    prepared = prepare_scrip_data(scrip_df, SEQ_LEN, n_ahead, TRAIN_RATIO)
    scaler = prepared["scaler"]
    X_train, y_train = prepared["X_train"], prepared["y_train"]
    X_test, y_test   = prepared["X_test"],  prepared["y_test"]

    # Check data sufficiency
    if len(X_train) == 0 or len(X_test) == 0:
        return {
            "scrip": scrip, "n_ahead": n_ahead, "status": "skipped",
            "reason": f"Not enough data after windowing (SEQ_LEN={SEQ_LEN}, N_AHEAD={n_ahead})."
        }

    input_shape = (X_train.shape[1], X_train.shape[2])  # (SEQ_LEN, n_features)

    # build & train
    model = build_lstm_model(input_shape, n_ahead)
    hist = model.fit(
        X_train, y_train,
        epochs=MAX_EPOCHS,
        batch_size=BATCH_SIZE,
        validation_split=VAL_SPLIT,
        verbose=0,
        callbacks=get_callbacks(),
        shuffle=False,  # keep order
    )

    # Evaluate on test
    y_pred_scaled = model.predict(X_test, verbose=0)
    # compute metrics per step across the horizon
    # inverse transform each horizon step separately
    # both y_test and y_pred_scaled have shape (samples, n_ahead)
    metrics = {}
    rmse_list, mape_list = [], []
    for step in range(n_ahead):
        y_true_step = inverse_transform_1d(y_test[:, step], scaler)
        y_pred_step = inverse_transform_1d(y_pred_scaled[:, step], scaler)
        rmse_list.append(rmse(y_true_step, y_pred_step))
        mape_list.append(mape(y_true_step, y_pred_step))
    metrics["rmse_per_step"] = rmse_list
    metrics["mape_per_step"] = mape_list
    metrics["rmse_mean"] = float(np.mean(rmse_list))
    metrics["mape_mean"] = float(np.mean(mape_list))

    # Save model & scaler (scaler once per scrip)
    scrip_dir = os.path.join(save_root, scrip)
    os.makedirs(scrip_dir, exist_ok=True)

    model_path = os.path.join(scrip_dir, f"lstm_{scrip}_seq{SEQ_LEN}_nahead{n_ahead}.keras")
    model.save(model_path)

    scaler_path = os.path.join(scrip_dir, f"scaler_{scrip}.bin")
    if not os.path.exists(scaler_path):
        joblib.dump(scaler, scaler_path)

    # Optional: save latest forecast (next n_ahead days) using last window of ALL data for that scrip
    # (fit scaler on train only already; we transform full scrip df with the same scaler)
    full_scaled = scaler.transform(scrip_df[FEATURE_COLS].values)
    if len(full_scaled) >= SEQ_LEN:
        last_window = full_scaled[-SEQ_LEN:]
        last_window = last_window.reshape(1, SEQ_LEN, full_scaled.shape[1])
        next_scaled = model.predict(last_window, verbose=0).ravel()
        next_unscaled = inverse_transform_1d(next_scaled, scaler)
        forecast_df = pd.DataFrame({
            "step_ahead": np.arange(1, n_ahead+1),
            "prediction": next_unscaled
        })
        forecast_path = os.path.join(scrip_dir, f"forecast_next_{n_ahead}.csv")
        forecast_df.to_csv(forecast_path, index=False)

    # Return record
    return {
        "scrip": scrip,
        "n_ahead": n_ahead,
        "status": "ok",
        "model_path": model_path,
        "scaler_path": scaler_path,
        "metrics": metrics,
    }

# %% [markdown]
# ## 6) Orchestration: Train all companies for 1/3/7-day horizons

# %%
# Load full dataset
df_all = read_all_data(CSV_PATH)

# Keep only needed columns
needed_cols = [DATE_COLUMN, SCRIP_COLUMN] + list(set(FEATURE_COLS + [TARGET_COLUMN]))
df_all = df_all[needed_cols].copy()

# For univariate Close-only, ensure FEATURE_COLS[0] == TARGET_COLUMN
if FEATURE_COLS[0] != TARGET_COLUMN:
    print("Note: Using multivariate features. TARGET_COLUMN must be among FEATURE_COLS; "
          "the first feature is treated as the target for inverse scaling.")

scrips = get_scrips(df_all)
print(f"Found {len(scrips)} scrips.")

records = []
for idx, scrip in enumerate(scrips, 1):
    scrip_df = df_all[df_all[SCRIP_COLUMN] == scrip].sort_values(DATE_COLUMN).reset_index(drop=True)

    # Basic NA handling
    scrip_df = scrip_df.dropna(subset=FEATURE_COLS)  # drop rows with missing features
    if len(scrip_df) < (SEQ_LEN + max(HORIZONS) + 10):  # conservative minimum
        print(f"[{idx}/{len(scrips)}] Skipping {scrip}: not enough rows ({len(scrip_df)}).")
        continue

    print(f"[{idx}/{len(scrips)}] Training {scrip} ...")
    for n_ahead in HORIZONS:
        result = train_one_horizon(scrip, scrip_df, n_ahead, save_root=MODELS_DIR)
        records.append({
            "scrip": scrip,
            "n_ahead": n_ahead,
            "status": result.get("status"),
            "model_path": result.get("model_path"),
            "scaler_path": result.get("scaler_path"),
            "rmse_mean": None if "metrics" not in result else result["metrics"]["rmse_mean"],
            "mape_mean": None if "metrics" not in result else result["metrics"]["mape_mean"],
        })
        if result.get("status") != "ok":
            print(f"  - {scrip} n_ahead={n_ahead}: {result.get('reason')}")
        else:
            print(f"  - {scrip} n_ahead={n_ahead}: OK")

# Save a CSV summary of metrics/paths
summary_df = pd.DataFrame(records)
summary_path = os.path.join(METRICS_DIR, "training_summary.csv")
summary_df.to_csv(summary_path, index=False)
print("Saved summary to:", summary_path)

summary_df.tail(10)
# Out:
# Found 464 scrips.
# [1/464] Training 00DS30 ...
#   - 00DS30 n_ahead=1: OK
#   - 00DS30 n_ahead=3: OK
#   - 00DS30 n_ahead=7: OK
# [2/464] Training 00DSES ...
#   - 00DSES n_ahead=1: OK
#   - 00DSES n_ahead=3: OK
#   - 00DSES n_ahead=7: OK
# [3/464] Training 00DSEX ...
#   - 00DSEX n_ahead=1: OK
#   - 00DSEX n_ahead=3: OK
#   - 00DSEX n_ahead=7: OK
# [4/464] Training 00DSMEX ...
#   - 00DSMEX n_ahead=1: OK
# WARNING:tensorflow:5 out of the last 37 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fad336c1620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 38 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fad336c1620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#   - 00DSMEX n_ahead=3: OK
#   - 00DSMEX n_ahead=7: OK
# [5/464] Training 1JANATAMF ...
#   - 1JANATAMF n_ahead=1: OK
#   - 1JANATAMF n_ahead=3: OK
#   - 1JANATAMF n_ahead=7: OK
# [6/464] Training 1STPRIMFMF ...
#   - 1STPRIMFMF n_ahead=1: OK
#   - 1STPRIMFMF n_ahead=3: OK
#   - 1STPRIMFMF n_ahead=7: OK
# [7/464] Training AAMRANET ...
#   - AAMRANET n_ahead=1: OK
#   - AAMRANET n_ahead=3: OK
#   - AAMRANET n_ahead=7: OK
# [8/464] Training AAMRATECH ...
#   - AAMRATECH n_ahead=1: OK
#   - AAMRATECH n_ahead=3: OK
#   - AAMRATECH n_ahead=7: OK
# [9/464] Training ABB1STMF ...
#   - ABB1STMF n_ahead=1: OK
#   - ABB1STMF n_ahead=3: OK
#   - ABB1STMF n_ahead=7: OK
# [10/464] Training ABBANK ...
#   - ABBANK n_ahead=1: OK
#   - ABBANK n_ahead=3: OK
#   - ABBANK n_ahead=7: OK
# [11/464] Training ABBLPBOND ...
#   - ABBLPBOND n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - ABBLPBOND n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - ABBLPBOND n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [12/464] Training ACFL ...
#   - ACFL n_ahead=1: OK
#   - ACFL n_ahead=3: OK
#   - ACFL n_ahead=7: OK
# [13/464] Training ACHIASF ...
#   - ACHIASF n_ahead=1: OK
#   - ACHIASF n_ahead=3: OK
#   - ACHIASF n_ahead=7: OK
# [14/464] Training ACI ...
#   - ACI n_ahead=1: OK
#   - ACI n_ahead=3: OK
#   - ACI n_ahead=7: OK
# [15/464] Training ACIFORMULA ...
#   - ACIFORMULA n_ahead=1: OK
#   - ACIFORMULA n_ahead=3: OK
#   - ACIFORMULA n_ahead=7: OK
# [16/464] Training ACMELAB ...
#   - ACMELAB n_ahead=1: OK
#   - ACMELAB n_ahead=3: OK
#   - ACMELAB n_ahead=7: OK
# [17/464] Training ACMEPL ...
#   - ACMEPL n_ahead=1: OK
#   - ACMEPL n_ahead=3: OK
#   - ACMEPL n_ahead=7: OK
# [18/464] Training ACTIVEFINE ...
#   - ACTIVEFINE n_ahead=1: OK
#   - ACTIVEFINE n_ahead=3: OK
#   - ACTIVEFINE n_ahead=7: OK
# [19/464] Training ADNTEL ...
#   - ADNTEL n_ahead=1: OK
#   - ADNTEL n_ahead=3: OK
#   - ADNTEL n_ahead=7: OK
# [20/464] Training ADVENT ...
#   - ADVENT n_ahead=1: OK
#   - ADVENT n_ahead=3: OK
#   - ADVENT n_ahead=7: OK
# [21/464] Training AFCAGRO ...
#   - AFCAGRO n_ahead=1: OK
#   - AFCAGRO n_ahead=3: OK
#   - AFCAGRO n_ahead=7: OK
# [22/464] Training AFTABAUTO ...
#   - AFTABAUTO n_ahead=1: OK
#   - AFTABAUTO n_ahead=3: OK
#   - AFTABAUTO n_ahead=7: OK
# [23/464] Training AGNISYSL ...
#   - AGNISYSL n_ahead=1: OK
#   - AGNISYSL n_ahead=3: OK
#   - AGNISYSL n_ahead=7: OK
# [24/464] Training AGRANINS ...
#   - AGRANINS n_ahead=1: OK
#   - AGRANINS n_ahead=3: OK
#   - AGRANINS n_ahead=7: OK
# [25/464] Training AIBL1STIMF ...
#   - AIBL1STIMF n_ahead=1: OK
#   - AIBL1STIMF n_ahead=3: OK
#   - AIBL1STIMF n_ahead=7: OK
# [26/464] Training AIL ...
#   - AIL n_ahead=1: OK
#   - AIL n_ahead=3: OK
#   - AIL n_ahead=7: OK
# [27/464] Training AL-HAJTEX ...
#   - AL-HAJTEX n_ahead=1: OK
#   - AL-HAJTEX n_ahead=3: OK
#   - AL-HAJTEX n_ahead=7: OK
# [28/464] Training ALARABANK ...
#   - ALARABANK n_ahead=1: OK
#   - ALARABANK n_ahead=3: OK
#   - ALARABANK n_ahead=7: OK
# [29/464] Training ALIF ...
#   - ALIF n_ahead=1: OK
#   - ALIF n_ahead=3: OK
#   - ALIF n_ahead=7: OK
# [30/464] Training ALLTEX ...
#   - ALLTEX n_ahead=1: OK
#   - ALLTEX n_ahead=3: OK
#   - ALLTEX n_ahead=7: OK
# [31/464] Training AMANFEED ...
#   - AMANFEED n_ahead=1: OK
#   - AMANFEED n_ahead=3: OK
#   - AMANFEED n_ahead=7: OK
# [32/464] Training AMBEEPHA ...
#   - AMBEEPHA n_ahead=1: OK
#   - AMBEEPHA n_ahead=3: OK
#   - AMBEEPHA n_ahead=7: OK
# [33/464] Training AMCL(PRAN) ...
#   - AMCL(PRAN) n_ahead=1: OK
#   - AMCL(PRAN) n_ahead=3: OK
#   - AMCL(PRAN) n_ahead=7: OK
# [34/464] Training AMPL ...
#   - AMPL n_ahead=1: OK
#   - AMPL n_ahead=3: OK
#   - AMPL n_ahead=7: OK
# [35/464] Training ANLIMAYARN ...
#   - ANLIMAYARN n_ahead=1: OK
#   - ANLIMAYARN n_ahead=3: OK
#   - ANLIMAYARN n_ahead=7: OK
# [36/464] Training ANWARGALV ...
#   - ANWARGALV n_ahead=1: OK
#   - ANWARGALV n_ahead=3: OK
#   - ANWARGALV n_ahead=7: OK
# [37/464] Training AOL ...
#   - AOL n_ahead=1: OK
#   - AOL n_ahead=3: OK
#   - AOL n_ahead=7: OK
# [38/464] Training AOPLC ...
#   - AOPLC n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - AOPLC n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - AOPLC n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [39/464] Training APEXFOODS ...
#   - APEXFOODS n_ahead=1: OK
#   - APEXFOODS n_ahead=3: OK
#   - APEXFOODS n_ahead=7: OK
# [40/464] Training APEXFOOT ...
#   - APEXFOOT n_ahead=1: OK
#   - APEXFOOT n_ahead=3: OK
#   - APEXFOOT n_ahead=7: OK
# [41/464] Training APEXSPINN ...
#   - APEXSPINN n_ahead=1: OK
#   - APEXSPINN n_ahead=3: OK
#   - APEXSPINN n_ahead=7: OK
# [42/464] Training APEXTANRY ...
#   - APEXTANRY n_ahead=1: OK
#   - APEXTANRY n_ahead=3: OK
#   - APEXTANRY n_ahead=7: OK
# [43/464] Training APEXWEAV ...
#   - APEXWEAV n_ahead=1: OK
#   - APEXWEAV n_ahead=3: OK
#   - APEXWEAV n_ahead=7: OK
# [44/464] Training APOLOISPAT ...
#   - APOLOISPAT n_ahead=1: OK
#   - APOLOISPAT n_ahead=3: OK
#   - APOLOISPAT n_ahead=7: OK
# [45/464] Training APSCLBOND ...
#   - APSCLBOND n_ahead=1: OK
#   - APSCLBOND n_ahead=3: OK
#   - APSCLBOND n_ahead=7: OK
# [46/464] Training ARAMIT ...
#   - ARAMIT n_ahead=1: OK
#   - ARAMIT n_ahead=3: OK
#   - ARAMIT n_ahead=7: OK
# [47/464] Training ARAMITCEM ...
#   - ARAMITCEM n_ahead=1: OK
#   - ARAMITCEM n_ahead=3: OK
#   - ARAMITCEM n_ahead=7: OK
# [48/464] Training ARGONDENIM ...
#   - ARGONDENIM n_ahead=1: OK
#   - ARGONDENIM n_ahead=3: OK
#   - ARGONDENIM n_ahead=7: OK
# [49/464] Training ASIAINS ...
#   - ASIAINS n_ahead=1: OK
#   - ASIAINS n_ahead=3: OK
#   - ASIAINS n_ahead=7: OK
# [50/464] Training ASIAPACINS ...
#   - ASIAPACINS n_ahead=1: OK
#   - ASIAPACINS n_ahead=3: OK
#   - ASIAPACINS n_ahead=7: OK
# [51/464] Training ASIATICLAB ...
#   - ASIATICLAB n_ahead=1: OK
#   - ASIATICLAB n_ahead=3: OK
#   - ASIATICLAB n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [52/464] Training ATCSLGF ...
#   - ATCSLGF n_ahead=1: OK
#   - ATCSLGF n_ahead=3: OK
#   - ATCSLGF n_ahead=7: OK
# [53/464] Training ATLASBANG ...
#   - ATLASBANG n_ahead=1: OK
#   - ATLASBANG n_ahead=3: OK
#   - ATLASBANG n_ahead=7: OK
# [54/464] Training AZIZPIPES ...
#   - AZIZPIPES n_ahead=1: OK
#   - AZIZPIPES n_ahead=3: OK
#   - AZIZPIPES n_ahead=7: OK
# [55/464] Training BANGAS ...
#   - BANGAS n_ahead=1: OK
#   - BANGAS n_ahead=3: OK
#   - BANGAS n_ahead=7: OK
# [56/464] Training BANKASI1PB ...
#   - BANKASI1PB n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - BANKASI1PB n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - BANKASI1PB n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [57/464] Training BANKASIA ...
#   - BANKASIA n_ahead=1: OK
#   - BANKASIA n_ahead=3: OK
#   - BANKASIA n_ahead=7: OK
# [58/464] Training BARKAPOWER ...
#   - BARKAPOWER n_ahead=1: OK
#   - BARKAPOWER n_ahead=3: OK
#   - BARKAPOWER n_ahead=7: OK
# [59/464] Training BATASHOE ...
#   - BATASHOE n_ahead=1: OK
#   - BATASHOE n_ahead=3: OK
#   - BATASHOE n_ahead=7: OK
# [60/464] Training BATBC ...
#   - BATBC n_ahead=1: OK
#   - BATBC n_ahead=3: OK
#   - BATBC n_ahead=7: OK
# [61/464] Training BAYLEASING ...
#   - BAYLEASING n_ahead=1: OK
#   - BAYLEASING n_ahead=3: OK
#   - BAYLEASING n_ahead=7: OK
# [62/464] Training BBS ...
#   - BBS n_ahead=1: OK
#   - BBS n_ahead=3: OK
#   - BBS n_ahead=7: OK
# [63/464] Training BBSCABLES ...
#   - BBSCABLES n_ahead=1: OK
#   - BBSCABLES n_ahead=3: OK
#   - BBSCABLES n_ahead=7: OK
# [64/464] Training BDAUTOCA ...
#   - BDAUTOCA n_ahead=1: OK
#   - BDAUTOCA n_ahead=3: OK
#   - BDAUTOCA n_ahead=7: OK
# [65/464] Training BDCOM ...
#   - BDCOM n_ahead=1: OK
#   - BDCOM n_ahead=3: OK
#   - BDCOM n_ahead=7: OK
# [66/464] Training BDFINANCE ...
#   - BDFINANCE n_ahead=1: OK
#   - BDFINANCE n_ahead=3: OK
#   - BDFINANCE n_ahead=7: OK
# [67/464] Training BDLAMPS ...
#   - BDLAMPS n_ahead=1: OK
#   - BDLAMPS n_ahead=3: OK
#   - BDLAMPS n_ahead=7: OK
# [68/464] Training BDPAINTS ...
#   - BDPAINTS n_ahead=1: OK
#   - BDPAINTS n_ahead=3: OK
#   - BDPAINTS n_ahead=7: OK
# [69/464] Training BDTHAI ...
#   - BDTHAI n_ahead=1: OK
#   - BDTHAI n_ahead=3: OK
#   - BDTHAI n_ahead=7: OK
# [70/464] Training BDTHAIFOOD ...
#   - BDTHAIFOOD n_ahead=1: OK
#   - BDTHAIFOOD n_ahead=3: OK
#   - BDTHAIFOOD n_ahead=7: OK
# [71/464] Training BDWELDING ...
#   - BDWELDING n_ahead=1: OK
#   - BDWELDING n_ahead=3: OK
#   - BDWELDING n_ahead=7: OK
# [72/464] Training BEACHHATCH ...
#   - BEACHHATCH n_ahead=1: OK
#   - BEACHHATCH n_ahead=3: OK
#   - BEACHHATCH n_ahead=7: OK
# [73/464] Training BEACONPHAR ...
#   - BEACONPHAR n_ahead=1: OK
#   - BEACONPHAR n_ahead=3: OK
#   - BEACONPHAR n_ahead=7: OK
# [74/464] Training BENGALBISC ...
#   - BENGALBISC n_ahead=1: OK
#   - BENGALBISC n_ahead=3: OK
#   - BENGALBISC n_ahead=7: OK
# [75/464] Training BENGALWTL ...
#   - BENGALWTL n_ahead=1: OK
#   - BENGALWTL n_ahead=3: OK
#   - BENGALWTL n_ahead=7: OK
# [76/464] Training BERGERPBL ...
#   - BERGERPBL n_ahead=1: OK
#   - BERGERPBL n_ahead=3: OK
#   - BERGERPBL n_ahead=7: OK
# [77/464] Training BESTHLDNG ...
#   - BESTHLDNG n_ahead=1: OK
#   - BESTHLDNG n_ahead=3: OK
#   - BESTHLDNG n_ahead=7: OK
# [78/464] Training BEXGSUKUK ...
#   - BEXGSUKUK n_ahead=1: OK
#   - BEXGSUKUK n_ahead=3: OK
#   - BEXGSUKUK n_ahead=7: OK
# [79/464] Training BEXIMCO ...
#   - BEXIMCO n_ahead=1: OK
#   - BEXIMCO n_ahead=3: OK
#   - BEXIMCO n_ahead=7: OK
# [80/464] Training BGIC ...
#   - BGIC n_ahead=1: OK
#   - BGIC n_ahead=3: OK
#   - BGIC n_ahead=7: OK
# [81/464] Training BIFC ...
#   - BIFC n_ahead=1: OK
#   - BIFC n_ahead=3: OK
#   - BIFC n_ahead=7: OK
# [82/464] Training BNICL ...
#   - BNICL n_ahead=1: OK
#   - BNICL n_ahead=3: OK
#   - BNICL n_ahead=7: OK
# [83/464] Training BPML ...
#   - BPML n_ahead=1: OK
#   - BPML n_ahead=3: OK
#   - BPML n_ahead=7: OK
# [84/464] Training BPPL ...
#   - BPPL n_ahead=1: OK
#   - BPPL n_ahead=3: OK
#   - BPPL n_ahead=7: OK
# [85/464] Training BRACBANK ...
#   - BRACBANK n_ahead=1: OK
#   - BRACBANK n_ahead=3: OK
#   - BRACBANK n_ahead=7: OK
# [86/464] Training BSC ...
#   - BSC n_ahead=1: OK
#   - BSC n_ahead=3: OK
#   - BSC n_ahead=7: OK
# [87/464] Training BSCPLC ...
#   - BSCPLC n_ahead=1: OK
#   - BSCPLC n_ahead=3: OK
#   - BSCPLC n_ahead=7: OK
# [88/464] Training BSRMLTD ...
#   - BSRMLTD n_ahead=1: OK
#   - BSRMLTD n_ahead=3: OK
#   - BSRMLTD n_ahead=7: OK
# [89/464] Training BSRMSTEEL ...
#   - BSRMSTEEL n_ahead=1: OK
#   - BSRMSTEEL n_ahead=3: OK
#   - BSRMSTEEL n_ahead=7: OK
# [90/464] Training BXPHARMA ...
#   - BXPHARMA n_ahead=1: OK
#   - BXPHARMA n_ahead=3: OK
#   - BXPHARMA n_ahead=7: OK
# [91/464] Training BXSYNTH ...
#   - BXSYNTH n_ahead=1: OK
#   - BXSYNTH n_ahead=3: OK
#   - BXSYNTH n_ahead=7: OK
# [92/464] Training CAPITECGBF ...
#   - CAPITECGBF n_ahead=1: OK
#   - CAPITECGBF n_ahead=3: OK
#   - CAPITECGBF n_ahead=7: OK
# [93/464] Training CAPMBDBLMF ...
#   - CAPMBDBLMF n_ahead=1: OK
#   - CAPMBDBLMF n_ahead=3: OK
#   - CAPMBDBLMF n_ahead=7: OK
# [94/464] Training CAPMIBBLMF ...
#   - CAPMIBBLMF n_ahead=1: OK
#   - CAPMIBBLMF n_ahead=3: OK
#   - CAPMIBBLMF n_ahead=7: OK
# [95/464] Training CBLPBOND ...
#   - CBLPBOND n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - CBLPBOND n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - CBLPBOND n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [96/464] Training CENTRALINS ...
#   - CENTRALINS n_ahead=1: OK
#   - CENTRALINS n_ahead=3: OK
#   - CENTRALINS n_ahead=7: OK
# [97/464] Training CENTRALPHL ...
#   - CENTRALPHL n_ahead=1: OK
#   - CENTRALPHL n_ahead=3: OK
#   - CENTRALPHL n_ahead=7: OK
# [98/464] Training CITYBANK ...
#   - CITYBANK n_ahead=1: OK
#   - CITYBANK n_ahead=3: OK
#   - CITYBANK n_ahead=7: OK
# [99/464] Training CITYGENINS ...
#   - CITYGENINS n_ahead=1: OK
#   - CITYGENINS n_ahead=3: OK
#   - CITYGENINS n_ahead=7: OK
# [100/464] Training CLICL ...
#   - CLICL n_ahead=1: OK
#   - CLICL n_ahead=3: OK
#   - CLICL n_ahead=7: OK
# [101/464] Training CNATEX ...
#   - CNATEX n_ahead=1: OK
#   - CNATEX n_ahead=3: OK
#   - CNATEX n_ahead=7: OK
# [102/464] Training CONFIDCEM ...
#   - CONFIDCEM n_ahead=1: OK
#   - CONFIDCEM n_ahead=3: OK
#   - CONFIDCEM n_ahead=7: OK
# [103/464] Training CONTININS ...
#   - CONTININS n_ahead=1: OK
#   - CONTININS n_ahead=3: OK
#   - CONTININS n_ahead=7: OK
# [104/464] Training COPPERTECH ...
#   - COPPERTECH n_ahead=1: OK
#   - COPPERTECH n_ahead=3: OK
#   - COPPERTECH n_ahead=7: OK
# [105/464] Training CRAFTSMAN ...
#   - CRAFTSMAN n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - CRAFTSMAN n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - CRAFTSMAN n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [106/464] Training CROWNCEMNT ...
#   - CROWNCEMNT n_ahead=1: OK
#   - CROWNCEMNT n_ahead=3: OK
#   - CROWNCEMNT n_ahead=7: OK
# [107/464] Training CRYSTALINS ...
#   - CRYSTALINS n_ahead=1: OK
#   - CRYSTALINS n_ahead=3: OK
#   - CRYSTALINS n_ahead=7: OK
# [108/464] Training CVOPRL ...
#   - CVOPRL n_ahead=1: OK
#   - CVOPRL n_ahead=3: OK
#   - CVOPRL n_ahead=7: OK
# [109/464] Training DACCADYE ...
#   - DACCADYE n_ahead=1: OK
#   - DACCADYE n_ahead=3: OK
#   - DACCADYE n_ahead=7: OK
# [110/464] Training DAFODILCOM ...
#   - DAFODILCOM n_ahead=1: OK
#   - DAFODILCOM n_ahead=3: OK
#   - DAFODILCOM n_ahead=7: OK
# [111/464] Training DBH ...
#   - DBH n_ahead=1: OK
#   - DBH n_ahead=3: OK
#   - DBH n_ahead=7: OK
# [112/464] Training DBH1STMF ...
#   - DBH1STMF n_ahead=1: OK
#   - DBH1STMF n_ahead=3: OK
#   - DBH1STMF n_ahead=7: OK
# [113/464] Training DBLPBOND ...
#   - DBLPBOND n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - DBLPBOND n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - DBLPBOND n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [114/464] Training DELTALIFE ...
#   - DELTALIFE n_ahead=1: OK
#   - DELTALIFE n_ahead=3: OK
#   - DELTALIFE n_ahead=7: OK
# [115/464] Training DELTASPINN ...
#   - DELTASPINN n_ahead=1: OK
#   - DELTASPINN n_ahead=3: OK
#   - DELTASPINN n_ahead=7: OK
# [116/464] Training DESCO ...
#   - DESCO n_ahead=1: OK
#   - DESCO n_ahead=3: OK
#   - DESCO n_ahead=7: OK
# [117/464] Training DESHBANDHU ...
#   - DESHBANDHU n_ahead=1: OK
#   - DESHBANDHU n_ahead=3: OK
#   - DESHBANDHU n_ahead=7: OK
# [118/464] Training DGIC ...
#   - DGIC n_ahead=1: OK
#   - DGIC n_ahead=3: OK
#   - DGIC n_ahead=7: OK
# [119/464] Training DHAKABANK ...
#   - DHAKABANK n_ahead=1: OK
#   - DHAKABANK n_ahead=3: OK
#   - DHAKABANK n_ahead=7: OK
# [120/464] Training DHAKAINS ...
#   - DHAKAINS n_ahead=1: OK
#   - DHAKAINS n_ahead=3: OK
#   - DHAKAINS n_ahead=7: OK
# [121/464] Training DOMINAGE ...
#   - DOMINAGE n_ahead=1: OK
#   - DOMINAGE n_ahead=3: OK
#   - DOMINAGE n_ahead=7: OK
# [122/464] Training DOREENPWR ...
#   - DOREENPWR n_ahead=1: OK
#   - DOREENPWR n_ahead=3: OK
#   - DOREENPWR n_ahead=7: OK
# [123/464] Training DSHGARME ...
#   - DSHGARME n_ahead=1: OK
#   - DSHGARME n_ahead=3: OK
#   - DSHGARME n_ahead=7: OK
# [124/464] Training DSSL ...
#   - DSSL n_ahead=1: OK
#   - DSSL n_ahead=3: OK
#   - DSSL n_ahead=7: OK
# [125/464] Training DULAMIACOT ...
#   - DULAMIACOT n_ahead=1: OK
#   - DULAMIACOT n_ahead=3: OK
#   - DULAMIACOT n_ahead=7: OK
# [126/464] Training DUTCHBANGL ...
#   - DUTCHBANGL n_ahead=1: OK
#   - DUTCHBANGL n_ahead=3: OK
#   - DUTCHBANGL n_ahead=7: OK
# [127/464] Training EASTERNINS ...
#   - EASTERNINS n_ahead=1: OK
#   - EASTERNINS n_ahead=3: OK
#   - EASTERNINS n_ahead=7: OK
# [128/464] Training EASTLAND ...
#   - EASTLAND n_ahead=1: OK
#   - EASTLAND n_ahead=3: OK
#   - EASTLAND n_ahead=7: OK
# [129/464] Training EASTRNLUB ...
#   - EASTRNLUB n_ahead=1: OK
#   - EASTRNLUB n_ahead=3: OK
#   - EASTRNLUB n_ahead=7: OK
# [130/464] Training EBL ...
#   - EBL n_ahead=1: OK
#   - EBL n_ahead=3: OK
#   - EBL n_ahead=7: OK
# [131/464] Training EBL1STMF ...
#   - EBL1STMF n_ahead=1: OK
#   - EBL1STMF n_ahead=3: OK
#   - EBL1STMF n_ahead=7: OK
# [132/464] Training EBLNRBMF ...
#   - EBLNRBMF n_ahead=1: OK
#   - EBLNRBMF n_ahead=3: OK
#   - EBLNRBMF n_ahead=7: OK
# [133/464] Training ECABLES ...
#   - ECABLES n_ahead=1: OK
#   - ECABLES n_ahead=3: OK
#   - ECABLES n_ahead=7: OK
# [134/464] Training EGEN ...
#   - EGEN n_ahead=1: OK
#   - EGEN n_ahead=3: OK
#   - EGEN n_ahead=7: OK
# [135/464] Training EHL ...
#   - EHL n_ahead=1: OK
#   - EHL n_ahead=3: OK
#   - EHL n_ahead=7: OK
# [136/464] Training EIL ...
#   - EIL n_ahead=1: OK
#   - EIL n_ahead=3: OK
#   - EIL n_ahead=7: OK
# [137/464] Training EMERALDOIL ...
#   - EMERALDOIL n_ahead=1: OK
#   - EMERALDOIL n_ahead=3: OK
#   - EMERALDOIL n_ahead=7: OK
# [138/464] Training ENVOYTEX ...
#   - ENVOYTEX n_ahead=1: OK
#   - ENVOYTEX n_ahead=3: OK
#   - ENVOYTEX n_ahead=7: OK
# [139/464] Training EPGL ...
#   - EPGL n_ahead=1: OK
#   - EPGL n_ahead=3: OK
#   - EPGL n_ahead=7: OK
# [140/464] Training ESQUIRENIT ...
#   - ESQUIRENIT n_ahead=1: OK
#   - ESQUIRENIT n_ahead=3: OK
#   - ESQUIRENIT n_ahead=7: OK
# [141/464] Training ETL ...
#   - ETL n_ahead=1: OK
#   - ETL n_ahead=3: OK
#   - ETL n_ahead=7: OK
# [142/464] Training EXIM1STMF ...
#   - EXIM1STMF n_ahead=1: OK
#   - EXIM1STMF n_ahead=3: OK
#   - EXIM1STMF n_ahead=7: OK
# [143/464] Training EXIMBANK ...
#   - EXIMBANK n_ahead=1: OK
#   - EXIMBANK n_ahead=3: OK
#   - EXIMBANK n_ahead=7: OK
# [144/464] Training FAMILYTEX ...
#   - FAMILYTEX n_ahead=1: OK
#   - FAMILYTEX n_ahead=3: OK
#   - FAMILYTEX n_ahead=7: OK
# [145/464] Training FARCHEM ...
#   - FARCHEM n_ahead=1: OK
#   - FARCHEM n_ahead=3: OK
#   - FARCHEM n_ahead=7: OK
# [146/464] Training FAREASTFIN ...
#   - FAREASTFIN n_ahead=1: OK
#   - FAREASTFIN n_ahead=3: OK
#   - FAREASTFIN n_ahead=7: OK
# [147/464] Training FAREASTLIF ...
#   - FAREASTLIF n_ahead=1: OK
#   - FAREASTLIF n_ahead=3: OK
#   - FAREASTLIF n_ahead=7: OK
# [148/464] Training FASFIN ...
#   - FASFIN n_ahead=1: OK
#   - FASFIN n_ahead=3: OK
#   - FASFIN n_ahead=7: OK
# [149/464] Training FBFIF ...
#   - FBFIF n_ahead=1: OK
#   - FBFIF n_ahead=3: OK
#   - FBFIF n_ahead=7: OK
# [150/464] Training FEDERALINS ...
#   - FEDERALINS n_ahead=1: OK
#   - FEDERALINS n_ahead=3: OK
#   - FEDERALINS n_ahead=7: OK
# [151/464] Training FEKDIL ...
#   - FEKDIL n_ahead=1: OK
#   - FEKDIL n_ahead=3: OK
#   - FEKDIL n_ahead=7: OK
# [152/464] Training FINEFOODS ...
#   - FINEFOODS n_ahead=1: OK
#   - FINEFOODS n_ahead=3: OK
#   - FINEFOODS n_ahead=7: OK
# [153/464] Training FIRSTFIN ...
#   - FIRSTFIN n_ahead=1: OK
#   - FIRSTFIN n_ahead=3: OK
#   - FIRSTFIN n_ahead=7: OK
# [154/464] Training FIRSTSBANK ...
#   - FIRSTSBANK n_ahead=1: OK
#   - FIRSTSBANK n_ahead=3: OK
#   - FIRSTSBANK n_ahead=7: OK
# [155/464] Training FORTUNE ...
#   - FORTUNE n_ahead=1: OK
#   - FORTUNE n_ahead=3: OK
#   - FORTUNE n_ahead=7: OK
# [156/464] Training FUWANGCER ...
#   - FUWANGCER n_ahead=1: OK
#   - FUWANGCER n_ahead=3: OK
#   - FUWANGCER n_ahead=7: OK
# [157/464] Training FUWANGFOOD ...
#   - FUWANGFOOD n_ahead=1: OK
#   - FUWANGFOOD n_ahead=3: OK
#   - FUWANGFOOD n_ahead=7: OK
# [158/464] Training GBBPOWER ...
#   - GBBPOWER n_ahead=1: OK
#   - GBBPOWER n_ahead=3: OK
#   - GBBPOWER n_ahead=7: OK
# [159/464] Training GEMINISEA ...
#   - GEMINISEA n_ahead=1: OK
#   - GEMINISEA n_ahead=3: OK
#   - GEMINISEA n_ahead=7: OK
# [160/464] Training GENEXIL ...
#   - GENEXIL n_ahead=1: OK
#   - GENEXIL n_ahead=3: OK
#   - GENEXIL n_ahead=7: OK
# [161/464] Training GENNEXT ...
#   - GENNEXT n_ahead=1: OK
#   - GENNEXT n_ahead=3: OK
#   - GENNEXT n_ahead=7: OK
# [162/464] Training GHAIL ...
#   - GHAIL n_ahead=1: OK
#   - GHAIL n_ahead=3: OK
#   - GHAIL n_ahead=7: OK
# [163/464] Training GHCL ...
#   - GHCL n_ahead=1: OK
#   - GHCL n_ahead=3: OK
#   - GHCL n_ahead=7: OK
# [164/464] Training GIB ...
#   - GIB n_ahead=1: OK
#   - GIB n_ahead=3: OK
#   - GIB n_ahead=7: OK
# [165/464] Training GLDNJMF ...
#   - GLDNJMF n_ahead=1: OK
#   - GLDNJMF n_ahead=3: OK
#   - GLDNJMF n_ahead=7: OK
# [166/464] Training GLOBALINS ...
#   - GLOBALINS n_ahead=1: OK
#   - GLOBALINS n_ahead=3: OK
#   - GLOBALINS n_ahead=7: OK
# [167/464] Training GOLDENSON ...
#   - GOLDENSON n_ahead=1: OK
#   - GOLDENSON n_ahead=3: OK
#   - GOLDENSON n_ahead=7: OK
# [168/464] Training GP ...
#   - GP n_ahead=1: OK
#   - GP n_ahead=3: OK
#   - GP n_ahead=7: OK
# [169/464] Training GPHISPAT ...
#   - GPHISPAT n_ahead=1: OK
#   - GPHISPAT n_ahead=3: OK
#   - GPHISPAT n_ahead=7: OK
# [170/464] Training GQBALLPEN ...
#   - GQBALLPEN n_ahead=1: OK
#   - GQBALLPEN n_ahead=3: OK
#   - GQBALLPEN n_ahead=7: OK
# [171/464] Training GRAMEENS2 ...
#   - GRAMEENS2 n_ahead=1: OK
#   - GRAMEENS2 n_ahead=3: OK
#   - GRAMEENS2 n_ahead=7: OK
# [172/464] Training GREENDELMF ...
#   - GREENDELMF n_ahead=1: OK
#   - GREENDELMF n_ahead=3: OK
#   - GREENDELMF n_ahead=7: OK
# [173/464] Training GREENDELT ...
#   - GREENDELT n_ahead=1: OK
#   - GREENDELT n_ahead=3: OK
#   - GREENDELT n_ahead=7: OK
# [174/464] Training GSPFINANCE ...
#   - GSPFINANCE n_ahead=1: OK
#   - GSPFINANCE n_ahead=3: OK
#   - GSPFINANCE n_ahead=7: OK
# [175/464] Training HAKKANIPUL ...
#   - HAKKANIPUL n_ahead=1: OK
#   - HAKKANIPUL n_ahead=3: OK
#   - HAKKANIPUL n_ahead=7: OK
# [176/464] Training HAMI ...
#   - HAMI n_ahead=1: OK
#   - HAMI n_ahead=3: OK
#   - HAMI n_ahead=7: OK
# [177/464] Training HEIDELBCEM ...
#   - HEIDELBCEM n_ahead=1: OK
#   - HEIDELBCEM n_ahead=3: OK
#   - HEIDELBCEM n_ahead=7: OK
# [178/464] Training HFL ...
#   - HFL n_ahead=1: OK
#   - HFL n_ahead=3: OK
#   - HFL n_ahead=7: OK
# [179/464] Training HIMADRI ...
#   - HIMADRI n_ahead=1: OK
#   - HIMADRI n_ahead=3: OK
#   - HIMADRI n_ahead=7: OK
# [180/464] Training HRTEX ...
#   - HRTEX n_ahead=1: OK
#   - HRTEX n_ahead=3: OK
#   - HRTEX n_ahead=7: OK
# [181/464] Training HWAWELLTEX ...
#   - HWAWELLTEX n_ahead=1: OK
#   - HWAWELLTEX n_ahead=3: OK
#   - HWAWELLTEX n_ahead=7: OK
# [182/464] Training IBNSINA ...
#   - IBNSINA n_ahead=1: OK
#   - IBNSINA n_ahead=3: OK
#   - IBNSINA n_ahead=7: OK
# [183/464] Training IBP ...
#   - IBP n_ahead=1: OK
#   - IBP n_ahead=3: OK
#   - IBP n_ahead=7: OK
# [184/464] Training ICB ...
#   - ICB n_ahead=1: OK
#   - ICB n_ahead=3: OK
#   - ICB n_ahead=7: OK
# [185/464] Training ICB3RDNRB ...
#   - ICB3RDNRB n_ahead=1: OK
#   - ICB3RDNRB n_ahead=3: OK
#   - ICB3RDNRB n_ahead=7: OK
# [186/464] Training ICBAGRANI1 ...
#   - ICBAGRANI1 n_ahead=1: OK
#   - ICBAGRANI1 n_ahead=3: OK
#   - ICBAGRANI1 n_ahead=7: OK
# [187/464] Training ICBAMCL2ND ...
#   - ICBAMCL2ND n_ahead=1: OK
#   - ICBAMCL2ND n_ahead=3: OK
#   - ICBAMCL2ND n_ahead=7: OK
# [188/464] Training ICBEPMF1S1 ...
#   - ICBEPMF1S1 n_ahead=1: OK
#   - ICBEPMF1S1 n_ahead=3: OK
#   - ICBEPMF1S1 n_ahead=7: OK
# [189/464] Training ICBIBANK ...
#   - ICBIBANK n_ahead=1: OK
#   - ICBIBANK n_ahead=3: OK
#   - ICBIBANK n_ahead=7: OK
# [190/464] Training ICBSONALI1 ...
#   - ICBSONALI1 n_ahead=1: OK
#   - ICBSONALI1 n_ahead=3: OK
#   - ICBSONALI1 n_ahead=7: OK
# [191/464] Training ICICL ...
#   - ICICL n_ahead=1: OK
#   - ICICL n_ahead=3: OK
#   - ICICL n_ahead=7: OK
# [192/464] Training IDLC ...
#   - IDLC n_ahead=1: OK
#   - IDLC n_ahead=3: OK
#   - IDLC n_ahead=7: OK
# [193/464] Training IFADAUTOS ...
#   - IFADAUTOS n_ahead=1: OK
#   - IFADAUTOS n_ahead=3: OK
#   - IFADAUTOS n_ahead=7: OK
# [194/464] Training IFIC ...
#   - IFIC n_ahead=1: OK
#   - IFIC n_ahead=3: OK
#   - IFIC n_ahead=7: OK
# [195/464] Training IFIC1STMF ...
#   - IFIC1STMF n_ahead=1: OK
#   - IFIC1STMF n_ahead=3: OK
#   - IFIC1STMF n_ahead=7: OK
# [196/464] Training IFILISLMF1 ...
#   - IFILISLMF1 n_ahead=1: OK
#   - IFILISLMF1 n_ahead=3: OK
#   - IFILISLMF1 n_ahead=7: OK
# [197/464] Training ILFSL ...
#   - ILFSL n_ahead=1: OK
#   - ILFSL n_ahead=3: OK
#   - ILFSL n_ahead=7: OK
# [198/464] Training INDEXAGRO ...
#   - INDEXAGRO n_ahead=1: OK
#   - INDEXAGRO n_ahead=3: OK
#   - INDEXAGRO n_ahead=7: OK
# [199/464] Training INTECH ...
#   - INTECH n_ahead=1: OK
#   - INTECH n_ahead=3: OK
#   - INTECH n_ahead=7: OK
# [200/464] Training INTRACO ...
#   - INTRACO n_ahead=1: OK
#   - INTRACO n_ahead=3: OK
#   - INTRACO n_ahead=7: OK
# [201/464] Training IPDC ...
#   - IPDC n_ahead=1: OK
#   - IPDC n_ahead=3: OK
#   - IPDC n_ahead=7: OK
# [202/464] Training ISLAMIBANK ...
#   - ISLAMIBANK n_ahead=1: OK
#   - ISLAMIBANK n_ahead=3: OK
#   - ISLAMIBANK n_ahead=7: OK
# [203/464] Training ISLAMICFIN ...
#   - ISLAMICFIN n_ahead=1: OK
#   - ISLAMICFIN n_ahead=3: OK
#   - ISLAMICFIN n_ahead=7: OK
# [204/464] Training ISLAMIINS ...
#   - ISLAMIINS n_ahead=1: OK
#   - ISLAMIINS n_ahead=3: OK
#   - ISLAMIINS n_ahead=7: OK
# [205/464] Training ISNLTD ...
#   - ISNLTD n_ahead=1: OK
#   - ISNLTD n_ahead=3: OK
#   - ISNLTD n_ahead=7: OK
# [206/464] Training ITC ...
#   - ITC n_ahead=1: OK
#   - ITC n_ahead=3: OK
#   - ITC n_ahead=7: OK
# [207/464] Training JAMUNABANK ...
#   - JAMUNABANK n_ahead=1: OK
#   - JAMUNABANK n_ahead=3: OK
#   - JAMUNABANK n_ahead=7: OK
# [208/464] Training JAMUNAOIL ...
#   - JAMUNAOIL n_ahead=1: OK
#   - JAMUNAOIL n_ahead=3: OK
#   - JAMUNAOIL n_ahead=7: OK
# [209/464] Training JANATAINS ...
#   - JANATAINS n_ahead=1: OK
#   - JANATAINS n_ahead=3: OK
#   - JANATAINS n_ahead=7: OK
# [210/464] Training JHRML ...
#   - JHRML n_ahead=1: OK
#   - JHRML n_ahead=3: OK
#   - JHRML n_ahead=7: OK
# [211/464] Training JMISMDL ...
#   - JMISMDL n_ahead=1: OK
#   - JMISMDL n_ahead=3: OK
#   - JMISMDL n_ahead=7: OK
# [212/464] Training JUTESPINN ...
#   - JUTESPINN n_ahead=1: OK
#   - JUTESPINN n_ahead=3: OK
#   - JUTESPINN n_ahead=7: OK
# [213/464] Training KARNAPHULI ...
#   - KARNAPHULI n_ahead=1: OK
#   - KARNAPHULI n_ahead=3: OK
#   - KARNAPHULI n_ahead=7: OK
# [214/464] Training KAY&QUE ...
#   - KAY&QUE n_ahead=1: OK
#   - KAY&QUE n_ahead=3: OK
#   - KAY&QUE n_ahead=7: OK
# [215/464] Training KBPPWBIL ...
#   - KBPPWBIL n_ahead=1: OK
#   - KBPPWBIL n_ahead=3: OK
#   - KBPPWBIL n_ahead=7: OK
# [216/464] Training KBSEED ...
#   - KBSEED n_ahead=1: OK
#   - KBSEED n_ahead=3: OK
#   - KBSEED n_ahead=7: OK
# [217/464] Training KDSALTD ...
#   - KDSALTD n_ahead=1: OK
#   - KDSALTD n_ahead=3: OK
#   - KDSALTD n_ahead=7: OK
# [218/464] Training KEYACOSMET ...
#   - KEYACOSMET n_ahead=1: OK
#   - KEYACOSMET n_ahead=3: OK
#   - KEYACOSMET n_ahead=7: OK
# [219/464] Training KFL ...
#   - KFL n_ahead=1: OK
#   - KFL n_ahead=3: OK
#   - KFL n_ahead=7: OK
# [220/464] Training KOHINOOR ...
#   - KOHINOOR n_ahead=1: OK
#   - KOHINOOR n_ahead=3: OK
#   - KOHINOOR n_ahead=7: OK
# [221/464] Training KPCL ...
#   - KPCL n_ahead=1: OK
#   - KPCL n_ahead=3: OK
#   - KPCL n_ahead=7: OK
# [222/464] Training KPPL ...
#   - KPPL n_ahead=1: OK
#   - KPPL n_ahead=3: OK
#   - KPPL n_ahead=7: OK
# [223/464] Training KTL ...
#   - KTL n_ahead=1: OK
#   - KTL n_ahead=3: OK
#   - KTL n_ahead=7: OK
# [224/464] Training LANKABAFIN ...
#   - LANKABAFIN n_ahead=1: OK
#   - LANKABAFIN n_ahead=3: OK
#   - LANKABAFIN n_ahead=7: OK
# [225/464] Training LEGACYFOOT ...
#   - LEGACYFOOT n_ahead=1: OK
#   - LEGACYFOOT n_ahead=3: OK
#   - LEGACYFOOT n_ahead=7: OK
# [226/464] Training LHB ...
#   - LHB n_ahead=1: OK
#   - LHB n_ahead=3: OK
#   - LHB n_ahead=7: OK
# [227/464] Training LIBRAINFU ...
#   - LIBRAINFU n_ahead=1: OK
#   - LIBRAINFU n_ahead=3: OK
#   - LIBRAINFU n_ahead=7: OK
# [228/464] Training LINDEBD ...
#   - LINDEBD n_ahead=1: OK
#   - LINDEBD n_ahead=3: OK
#   - LINDEBD n_ahead=7: OK
# [229/464] Training LOVELLO ...
#   - LOVELLO n_ahead=1: OK
#   - LOVELLO n_ahead=3: OK
#   - LOVELLO n_ahead=7: OK
# [230/464] Training LRBDL ...
#   - LRBDL n_ahead=1: OK
#   - LRBDL n_ahead=3: OK
#   - LRBDL n_ahead=7: OK
# [231/464] Training LRGLOBMF1 ...
#   - LRGLOBMF1 n_ahead=1: OK
#   - LRGLOBMF1 n_ahead=3: OK
#   - LRGLOBMF1 n_ahead=7: OK
# [232/464] Training MAKSONSPIN ...
#   - MAKSONSPIN n_ahead=1: OK
#   - MAKSONSPIN n_ahead=3: OK
#   - MAKSONSPIN n_ahead=7: OK
# [233/464] Training MALEKSPIN ...
#   - MALEKSPIN n_ahead=1: OK
#   - MALEKSPIN n_ahead=3: OK
#   - MALEKSPIN n_ahead=7: OK
# [234/464] Training MAMUNAGRO ...
#   - MAMUNAGRO n_ahead=1: OK
#   - MAMUNAGRO n_ahead=3: OK
#   - MAMUNAGRO n_ahead=7: OK
# [235/464] Training MARICO ...
#   - MARICO n_ahead=1: OK
#   - MARICO n_ahead=3: OK
#   - MARICO n_ahead=7: OK
# [236/464] Training MASTERAGRO ...
#   - MASTERAGRO n_ahead=1: OK
#   - MASTERAGRO n_ahead=3: OK
#   - MASTERAGRO n_ahead=7: OK
# [237/464] Training MATINSPINN ...
#   - MATINSPINN n_ahead=1: OK
#   - MATINSPINN n_ahead=3: OK
#   - MATINSPINN n_ahead=7: OK
# [238/464] Training MBL1STMF ...
#   - MBL1STMF n_ahead=1: OK
#   - MBL1STMF n_ahead=3: OK
#   - MBL1STMF n_ahead=7: OK
# [239/464] Training MBPLCPBOND ...
#   - MBPLCPBOND n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - MBPLCPBOND n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - MBPLCPBOND n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [240/464] Training MEGCONMILK ...
#   - MEGCONMILK n_ahead=1: OK
#   - MEGCONMILK n_ahead=3: OK
#   - MEGCONMILK n_ahead=7: OK
# [241/464] Training MEGHNACEM ...
#   - MEGHNACEM n_ahead=1: OK
#   - MEGHNACEM n_ahead=3: OK
#   - MEGHNACEM n_ahead=7: OK
# [242/464] Training MEGHNAINS ...
#   - MEGHNAINS n_ahead=1: OK
#   - MEGHNAINS n_ahead=3: OK
#   - MEGHNAINS n_ahead=7: OK
# [243/464] Training MEGHNALIFE ...
#   - MEGHNALIFE n_ahead=1: OK
#   - MEGHNALIFE n_ahead=3: OK
#   - MEGHNALIFE n_ahead=7: OK
# [244/464] Training MEGHNAPET ...
#   - MEGHNAPET n_ahead=1: OK
#   - MEGHNAPET n_ahead=3: OK
#   - MEGHNAPET n_ahead=7: OK
# [245/464] Training MERCANBANK ...
#   - MERCANBANK n_ahead=1: OK
#   - MERCANBANK n_ahead=3: OK
#   - MERCANBANK n_ahead=7: OK
# [246/464] Training MERCINS ...
#   - MERCINS n_ahead=1: OK
#   - MERCINS n_ahead=3: OK
#   - MERCINS n_ahead=7: OK
# [247/464] Training METROSPIN ...
#   - METROSPIN n_ahead=1: OK
#   - METROSPIN n_ahead=3: OK
#   - METROSPIN n_ahead=7: OK
# [248/464] Training MHSML ...
#   - MHSML n_ahead=1: OK
#   - MHSML n_ahead=3: OK
#   - MHSML n_ahead=7: OK
# [249/464] Training MIDASFIN ...
#   - MIDASFIN n_ahead=1: OK
#   - MIDASFIN n_ahead=3: OK
#   - MIDASFIN n_ahead=7: OK
# [250/464] Training MIDLANDBNK ...
#   - MIDLANDBNK n_ahead=1: OK
#   - MIDLANDBNK n_ahead=3: OK
#   - MIDLANDBNK n_ahead=7: OK
# [251/464] Training MIRACLEIND ...
#   - MIRACLEIND n_ahead=1: OK
#   - MIRACLEIND n_ahead=3: OK
#   - MIRACLEIND n_ahead=7: OK
# [252/464] Training MIRAKHTER ...
#   - MIRAKHTER n_ahead=1: OK
#   - MIRAKHTER n_ahead=3: OK
#   - MIRAKHTER n_ahead=7: OK
# [253/464] Training MITHUNKNIT ...
#   - MITHUNKNIT n_ahead=1: OK
#   - MITHUNKNIT n_ahead=3: OK
#   - MITHUNKNIT n_ahead=7: OK
# [254/464] Training MJLBD ...
#   - MJLBD n_ahead=1: OK
#   - MJLBD n_ahead=3: OK
#   - MJLBD n_ahead=7: OK
# [255/464] Training MKFOOTWEAR ...
#   - MKFOOTWEAR n_ahead=1: OK
#   - MKFOOTWEAR n_ahead=3: OK
#   - MKFOOTWEAR n_ahead=7: OK
# [256/464] Training MLDYEING ...
#   - MLDYEING n_ahead=1: OK
#   - MLDYEING n_ahead=3: OK
#   - MLDYEING n_ahead=7: OK
# [257/464] Training MONNOAGML ...
#   - MONNOAGML n_ahead=1: OK
#   - MONNOAGML n_ahead=3: OK
#   - MONNOAGML n_ahead=7: OK
# [258/464] Training MONNOCERA ...
#   - MONNOCERA n_ahead=1: OK
#   - MONNOCERA n_ahead=3: OK
#   - MONNOCERA n_ahead=7: OK
# [259/464] Training MONNOFABR ...
#   - MONNOFABR n_ahead=1: OK
#   - MONNOFABR n_ahead=3: OK
#   - MONNOFABR n_ahead=7: OK
# [260/464] Training MONOSPOOL ...
#   - MONOSPOOL n_ahead=1: OK
#   - MONOSPOOL n_ahead=3: OK
#   - MONOSPOOL n_ahead=7: OK
# [261/464] Training MOSTFAMETL ...
#   - MOSTFAMETL n_ahead=1: OK
#   - MOSTFAMETL n_ahead=3: OK
#   - MOSTFAMETL n_ahead=7: OK
# [262/464] Training MPETROLEUM ...
#   - MPETROLEUM n_ahead=1: OK
#   - MPETROLEUM n_ahead=3: OK
#   - MPETROLEUM n_ahead=7: OK
# [263/464] Training MTB ...
#   - MTB n_ahead=1: OK
#   - MTB n_ahead=3: OK
#   - MTB n_ahead=7: OK
# [264/464] Training NAHEEACP ...
#   - NAHEEACP n_ahead=1: OK
#   - NAHEEACP n_ahead=3: OK
#   - NAHEEACP n_ahead=7: OK
# [265/464] Training NATLIFEINS ...
#   - NATLIFEINS n_ahead=1: OK
#   - NATLIFEINS n_ahead=3: OK
#   - NATLIFEINS n_ahead=7: OK
# [266/464] Training NAVANACNG ...
#   - NAVANACNG n_ahead=1: OK
#   - NAVANACNG n_ahead=3: OK
#   - NAVANACNG n_ahead=7: OK
# [267/464] Training NAVANAPHAR ...
#   - NAVANAPHAR n_ahead=1: OK
#   - NAVANAPHAR n_ahead=3: OK
#   - NAVANAPHAR n_ahead=7: OK
# [268/464] Training NBL ...
#   - NBL n_ahead=1: OK
#   - NBL n_ahead=3: OK
#   - NBL n_ahead=7: OK
# [269/464] Training NCCBANK ...
#   - NCCBANK n_ahead=1: OK
#   - NCCBANK n_ahead=3: OK
#   - NCCBANK n_ahead=7: OK
# [270/464] Training NCCBLMF1 ...
#   - NCCBLMF1 n_ahead=1: OK
#   - NCCBLMF1 n_ahead=3: OK
#   - NCCBLMF1 n_ahead=7: OK
# [271/464] Training NEWLINE ...
#   - NEWLINE n_ahead=1: OK
#   - NEWLINE n_ahead=3: OK
#   - NEWLINE n_ahead=7: OK
# [272/464] Training NFML ...
#   - NFML n_ahead=1: OK
#   - NFML n_ahead=3: OK
#   - NFML n_ahead=7: OK
# [273/464] Training NHFIL ...
#   - NHFIL n_ahead=1: OK
#   - NHFIL n_ahead=3: OK
#   - NHFIL n_ahead=7: OK
# [274/464] Training NIALCO ...
#   - NIALCO n_ahead=1: OK
#   - NIALCO n_ahead=3: OK
#   - NIALCO n_ahead=7: OK
# [275/464] Training NITOLINS ...
#   - NITOLINS n_ahead=1: OK
#   - NITOLINS n_ahead=3: OK
#   - NITOLINS n_ahead=7: OK
# [276/464] Training NORTHERN ...
#   - NORTHERN n_ahead=1: OK
#   - NORTHERN n_ahead=3: OK
#   - NORTHERN n_ahead=7: OK
# [277/464] Training NORTHRNINS ...
#   - NORTHRNINS n_ahead=1: OK
#   - NORTHRNINS n_ahead=3: OK
#   - NORTHRNINS n_ahead=7: OK
# [278/464] Training NPOLYMER ...
#   - NPOLYMER n_ahead=1: OK
#   - NPOLYMER n_ahead=3: OK
#   - NPOLYMER n_ahead=7: OK
# [279/464] Training NRBBANK ...
#   - NRBBANK n_ahead=1: OK
#   - NRBBANK n_ahead=3: OK
#   - NRBBANK n_ahead=7: OK
# [280/464] Training NRBCBANK ...
#   - NRBCBANK n_ahead=1: OK
#   - NRBCBANK n_ahead=3: OK
#   - NRBCBANK n_ahead=7: OK
# [281/464] Training NTC ...
#   - NTC n_ahead=1: OK
#   - NTC n_ahead=3: OK
#   - NTC n_ahead=7: OK
# [282/464] Training NTLTUBES ...
#   - NTLTUBES n_ahead=1: OK
#   - NTLTUBES n_ahead=3: OK
#   - NTLTUBES n_ahead=7: OK
# [283/464] Training NURANI ...
#   - NURANI n_ahead=1: OK
#   - NURANI n_ahead=3: OK
#   - NURANI n_ahead=7: OK
# [284/464] Training OAL ...
#   - OAL n_ahead=1: OK
#   - OAL n_ahead=3: OK
#   - OAL n_ahead=7: OK
# [285/464] Training OIMEX ...
#   - OIMEX n_ahead=1: OK
#   - OIMEX n_ahead=3: OK
#   - OIMEX n_ahead=7: OK
# [286/464] Training OLYMPIC ...
#   - OLYMPIC n_ahead=1: OK
#   - OLYMPIC n_ahead=3: OK
#   - OLYMPIC n_ahead=7: OK
# [287/464] Training ONEBANKPLC ...
#   - ONEBANKPLC n_ahead=1: OK
#   - ONEBANKPLC n_ahead=3: OK
#   - ONEBANKPLC n_ahead=7: OK
# [288/464] Training ORIONINFU ...
#   - ORIONINFU n_ahead=1: OK
#   - ORIONINFU n_ahead=3: OK
#   - ORIONINFU n_ahead=7: OK
# [289/464] Training ORIONPHARM ...
#   - ORIONPHARM n_ahead=1: OK
#   - ORIONPHARM n_ahead=3: OK
#   - ORIONPHARM n_ahead=7: OK
# [290/464] Training ORYZAAGRO ...
#   - ORYZAAGRO n_ahead=1: OK
#   - ORYZAAGRO n_ahead=3: OK
#   - ORYZAAGRO n_ahead=7: OK
# [291/464] Training PADMALIFE ...
#   - PADMALIFE n_ahead=1: OK
#   - PADMALIFE n_ahead=3: OK
#   - PADMALIFE n_ahead=7: OK
# [292/464] Training PADMAOIL ...
#   - PADMAOIL n_ahead=1: OK
#   - PADMAOIL n_ahead=3: OK
#   - PADMAOIL n_ahead=7: OK
# [293/464] Training PAPERPROC ...
#   - PAPERPROC n_ahead=1: OK
#   - PAPERPROC n_ahead=3: OK
#   - PAPERPROC n_ahead=7: OK
# [294/464] Training PARAMOUNT ...
#   - PARAMOUNT n_ahead=1: OK
#   - PARAMOUNT n_ahead=3: OK
#   - PARAMOUNT n_ahead=7: OK
# [295/464] Training PDL ...
#   - PDL n_ahead=1: OK
#   - PDL n_ahead=3: OK
#   - PDL n_ahead=7: OK
# [296/464] Training PENINSULA ...
#   - PENINSULA n_ahead=1: OK
#   - PENINSULA n_ahead=3: OK
#   - PENINSULA n_ahead=7: OK
# [297/464] Training PEOPLESINS ...
#   - PEOPLESINS n_ahead=1: OK
#   - PEOPLESINS n_ahead=3: OK
#   - PEOPLESINS n_ahead=7: OK
# [298/464] Training PF1STMF ...
#   - PF1STMF n_ahead=1: OK
#   - PF1STMF n_ahead=3: OK
#   - PF1STMF n_ahead=7: OK
# [299/464] Training PHARMAID ...
#   - PHARMAID n_ahead=1: OK
#   - PHARMAID n_ahead=3: OK
#   - PHARMAID n_ahead=7: OK
# [300/464] Training PHENIXINS ...
#   - PHENIXINS n_ahead=1: OK
#   - PHENIXINS n_ahead=3: OK
#   - PHENIXINS n_ahead=7: OK
# [301/464] Training PHOENIXFIN ...
#   - PHOENIXFIN n_ahead=1: OK
#   - PHOENIXFIN n_ahead=3: OK
#   - PHOENIXFIN n_ahead=7: OK
# [302/464] Training PHPMF1 ...
#   - PHPMF1 n_ahead=1: OK
#   - PHPMF1 n_ahead=3: OK
#   - PHPMF1 n_ahead=7: OK
# [303/464] Training PIONEERINS ...
#   - PIONEERINS n_ahead=1: OK
#   - PIONEERINS n_ahead=3: OK
#   - PIONEERINS n_ahead=7: OK
# [304/464] Training PLFSL ...
#   - PLFSL n_ahead=1: OK
#   - PLFSL n_ahead=3: OK
#   - PLFSL n_ahead=7: OK
# [305/464] Training POPULAR1MF ...
#   - POPULAR1MF n_ahead=1: OK
#   - POPULAR1MF n_ahead=3: OK
#   - POPULAR1MF n_ahead=7: OK
# [306/464] Training POPULARLIF ...
#   - POPULARLIF n_ahead=1: OK
#   - POPULARLIF n_ahead=3: OK
#   - POPULARLIF n_ahead=7: OK
# [307/464] Training POWERGRID ...
#   - POWERGRID n_ahead=1: OK
#   - POWERGRID n_ahead=3: OK
#   - POWERGRID n_ahead=7: OK
# [308/464] Training PRAGATIINS ...
#   - PRAGATIINS n_ahead=1: OK
#   - PRAGATIINS n_ahead=3: OK
#   - PRAGATIINS n_ahead=7: OK
# [309/464] Training PRAGATILIF ...
#   - PRAGATILIF n_ahead=1: OK
#   - PRAGATILIF n_ahead=3: OK
#   - PRAGATILIF n_ahead=7: OK
# [310/464] Training PREMIERBAN ...
#   - PREMIERBAN n_ahead=1: OK
#   - PREMIERBAN n_ahead=3: OK
#   - PREMIERBAN n_ahead=7: OK
# [311/464] Training PREMIERCEM ...
#   - PREMIERCEM n_ahead=1: OK
#   - PREMIERCEM n_ahead=3: OK
#   - PREMIERCEM n_ahead=7: OK
# [312/464] Training PREMIERLEA ...
#   - PREMIERLEA n_ahead=1: OK
#   - PREMIERLEA n_ahead=3: OK
#   - PREMIERLEA n_ahead=7: OK
# [313/464] Training PRIME1ICBA ...
#   - PRIME1ICBA n_ahead=1: OK
#   - PRIME1ICBA n_ahead=3: OK
#   - PRIME1ICBA n_ahead=7: OK
# [314/464] Training PRIMEBANK ...
#   - PRIMEBANK n_ahead=1: OK
#   - PRIMEBANK n_ahead=3: OK
#   - PRIMEBANK n_ahead=7: OK
# [315/464] Training PRIMEFIN ...
#   - PRIMEFIN n_ahead=1: OK
#   - PRIMEFIN n_ahead=3: OK
#   - PRIMEFIN n_ahead=7: OK
# [316/464] Training PRIMEINSUR ...
#   - PRIMEINSUR n_ahead=1: OK
#   - PRIMEINSUR n_ahead=3: OK
#   - PRIMEINSUR n_ahead=7: OK
# [317/464] Training PRIMELIFE ...
#   - PRIMELIFE n_ahead=1: OK
#   - PRIMELIFE n_ahead=3: OK
#   - PRIMELIFE n_ahead=7: OK
# [318/464] Training PRIMETEX ...
#   - PRIMETEX n_ahead=1: OK
#   - PRIMETEX n_ahead=3: OK
#   - PRIMETEX n_ahead=7: OK
# [319/464] Training PROGRESLIF ...
#   - PROGRESLIF n_ahead=1: OK
#   - PROGRESLIF n_ahead=3: OK
#   - PROGRESLIF n_ahead=7: OK
# [320/464] Training PROVATIINS ...
#   - PROVATIINS n_ahead=1: OK
#   - PROVATIINS n_ahead=3: OK
#   - PROVATIINS n_ahead=7: OK
# [321/464] Training PTL ...
#   - PTL n_ahead=1: OK
#   - PTL n_ahead=3: OK
#   - PTL n_ahead=7: OK
# [322/464] Training PUBALIBANK ...
#   - PUBALIBANK n_ahead=1: OK
#   - PUBALIBANK n_ahead=3: OK
#   - PUBALIBANK n_ahead=7: OK
# [323/464] Training PURABIGEN ...
#   - PURABIGEN n_ahead=1: OK
#   - PURABIGEN n_ahead=3: OK
#   - PURABIGEN n_ahead=7: OK
# [324/464] Training QUASEMIND ...
#   - QUASEMIND n_ahead=1: OK
#   - QUASEMIND n_ahead=3: OK
#   - QUASEMIND n_ahead=7: OK
# [325/464] Training QUEENSOUTH ...
#   - QUEENSOUTH n_ahead=1: OK
#   - QUEENSOUTH n_ahead=3: OK
#   - QUEENSOUTH n_ahead=7: OK
# [326/464] Training RAHIMAFOOD ...
#   - RAHIMAFOOD n_ahead=1: OK
#   - RAHIMAFOOD n_ahead=3: OK
#   - RAHIMAFOOD n_ahead=7: OK
# [327/464] Training RAHIMTEXT ...
#   - RAHIMTEXT n_ahead=1: OK
#   - RAHIMTEXT n_ahead=3: OK
#   - RAHIMTEXT n_ahead=7: OK
# [328/464] Training RAKCERAMIC ...
#   - RAKCERAMIC n_ahead=1: OK
#   - RAKCERAMIC n_ahead=3: OK
#   - RAKCERAMIC n_ahead=7: OK
# [329/464] Training RANFOUNDRY ...
#   - RANFOUNDRY n_ahead=1: OK
#   - RANFOUNDRY n_ahead=3: OK
#   - RANFOUNDRY n_ahead=7: OK
# [330/464] Training RDFOOD ...
#   - RDFOOD n_ahead=1: OK
#   - RDFOOD n_ahead=3: OK
#   - RDFOOD n_ahead=7: OK
# [331/464] Training RECKITTBEN ...
#   - RECKITTBEN n_ahead=1: OK
#   - RECKITTBEN n_ahead=3: OK
#   - RECKITTBEN n_ahead=7: OK
# [332/464] Training REGENTTEX ...
#   - REGENTTEX n_ahead=1: OK
#   - REGENTTEX n_ahead=3: OK
#   - REGENTTEX n_ahead=7: OK
# [333/464] Training RELIANCE1 ...
#   - RELIANCE1 n_ahead=1: OK
#   - RELIANCE1 n_ahead=3: OK
#   - RELIANCE1 n_ahead=7: OK
# [334/464] Training RELIANCINS ...
#   - RELIANCINS n_ahead=1: OK
#   - RELIANCINS n_ahead=3: OK
#   - RELIANCINS n_ahead=7: OK
# [335/464] Training RENATA ...
#   - RENATA n_ahead=1: OK
#   - RENATA n_ahead=3: OK
#   - RENATA n_ahead=7: OK
# [336/464] Training RENWICKJA ...
#   - RENWICKJA n_ahead=1: OK
#   - RENWICKJA n_ahead=3: OK
#   - RENWICKJA n_ahead=7: OK
# [337/464] Training REPUBLIC ...
#   - REPUBLIC n_ahead=1: OK
#   - REPUBLIC n_ahead=3: OK
#   - REPUBLIC n_ahead=7: OK
# [338/464] Training RINGSHINE ...
#   - RINGSHINE n_ahead=1: OK
#   - RINGSHINE n_ahead=3: OK
#   - RINGSHINE n_ahead=7: OK
# [339/464] Training RNSPIN ...
#   - RNSPIN n_ahead=1: OK
#   - RNSPIN n_ahead=3: OK
#   - RNSPIN n_ahead=7: OK
# [340/464] Training ROBI ...
#   - ROBI n_ahead=1: OK
#   - ROBI n_ahead=3: OK
#   - ROBI n_ahead=7: OK
# [341/464] Training RSRMSTEEL ...
#   - RSRMSTEEL n_ahead=1: OK
#   - RSRMSTEEL n_ahead=3: OK
#   - RSRMSTEEL n_ahead=7: OK
# [342/464] Training RUNNERAUTO ...
#   - RUNNERAUTO n_ahead=1: OK
#   - RUNNERAUTO n_ahead=3: OK
#   - RUNNERAUTO n_ahead=7: OK
# [343/464] Training RUPALIBANK ...
#   - RUPALIBANK n_ahead=1: OK
#   - RUPALIBANK n_ahead=3: OK
#   - RUPALIBANK n_ahead=7: OK
# [344/464] Training RUPALIINS ...
#   - RUPALIINS n_ahead=1: OK
#   - RUPALIINS n_ahead=3: OK
#   - RUPALIINS n_ahead=7: OK
# [345/464] Training RUPALILIFE ...
#   - RUPALILIFE n_ahead=1: OK
#   - RUPALILIFE n_ahead=3: OK
#   - RUPALILIFE n_ahead=7: OK
# [346/464] Training SADHESIVE ...
#   - SADHESIVE n_ahead=1: OK
#   - SADHESIVE n_ahead=3: OK
#   - SADHESIVE n_ahead=7: OK
# [347/464] Training SAFKOSPINN ...
#   - SAFKOSPINN n_ahead=1: OK
#   - SAFKOSPINN n_ahead=3: OK
#   - SAFKOSPINN n_ahead=7: OK
# [348/464] Training SAIFPOWER ...
#   - SAIFPOWER n_ahead=1: OK
#   - SAIFPOWER n_ahead=3: OK
#   - SAIFPOWER n_ahead=7: OK
# [349/464] Training SAIHAMCOT ...
#   - SAIHAMCOT n_ahead=1: OK
#   - SAIHAMCOT n_ahead=3: OK
#   - SAIHAMCOT n_ahead=7: OK
# [350/464] Training SAIHAMTEX ...
#   - SAIHAMTEX n_ahead=1: OK
#   - SAIHAMTEX n_ahead=3: OK
#   - SAIHAMTEX n_ahead=7: OK
# [351/464] Training SALAMCRST ...
#   - SALAMCRST n_ahead=1: OK
#   - SALAMCRST n_ahead=3: OK
#   - SALAMCRST n_ahead=7: OK
# [352/464] Training SALVOCHEM ...
#   - SALVOCHEM n_ahead=1: OK
#   - SALVOCHEM n_ahead=3: OK
#   - SALVOCHEM n_ahead=7: OK
# [353/464] Training SAMATALETH ...
#   - SAMATALETH n_ahead=1: OK
#   - SAMATALETH n_ahead=3: OK
#   - SAMATALETH n_ahead=7: OK
# [354/464] Training SAMORITA ...
#   - SAMORITA n_ahead=1: OK
#   - SAMORITA n_ahead=3: OK
#   - SAMORITA n_ahead=7: OK
# [355/464] Training SANDHANINS ...
#   - SANDHANINS n_ahead=1: OK
#   - SANDHANINS n_ahead=3: OK
#   - SANDHANINS n_ahead=7: OK
# [356/464] Training SAPORTL ...
#   - SAPORTL n_ahead=1: OK
#   - SAPORTL n_ahead=3: OK
#   - SAPORTL n_ahead=7: OK
# [357/464] Training SAVAREFR ...
#   - SAVAREFR n_ahead=1: OK
#   - SAVAREFR n_ahead=3: OK
#   - SAVAREFR n_ahead=7: OK
# [358/464] Training SBACBANK ...
#   - SBACBANK n_ahead=1: OK
#   - SBACBANK n_ahead=3: OK
#   - SBACBANK n_ahead=7: OK
# [359/464] Training SEAPEARL ...
#   - SEAPEARL n_ahead=1: OK
#   - SEAPEARL n_ahead=3: OK
#   - SEAPEARL n_ahead=7: OK
# [360/464] Training SEB1PBOND ...
#   - SEB1PBOND n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - SEB1PBOND n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - SEB1PBOND n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [361/464] Training SEMLFBSLGF ...
#   - SEMLFBSLGF n_ahead=1: OK
#   - SEMLFBSLGF n_ahead=3: OK
#   - SEMLFBSLGF n_ahead=7: OK
# [362/464] Training SEMLIBBLSF ...
#   - SEMLIBBLSF n_ahead=1: OK
#   - SEMLIBBLSF n_ahead=3: OK
#   - SEMLIBBLSF n_ahead=7: OK
# [363/464] Training SEMLLECMF ...
#   - SEMLLECMF n_ahead=1: OK
#   - SEMLLECMF n_ahead=3: OK
#   - SEMLLECMF n_ahead=7: OK
# [364/464] Training SHAHJABANK ...
#   - SHAHJABANK n_ahead=1: OK
#   - SHAHJABANK n_ahead=3: OK
#   - SHAHJABANK n_ahead=7: OK
# [365/464] Training SHARPIND ...
#   - SHARPIND n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - SHARPIND n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - SHARPIND n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [366/464] Training SHASHADNIM ...
#   - SHASHADNIM n_ahead=1: OK
#   - SHASHADNIM n_ahead=3: OK
#   - SHASHADNIM n_ahead=7: OK
# [367/464] Training SHEPHERD ...
#   - SHEPHERD n_ahead=1: OK
#   - SHEPHERD n_ahead=3: OK
#   - SHEPHERD n_ahead=7: OK
# [368/464] Training SHURWID ...
#   - SHURWID n_ahead=1: OK
#   - SHURWID n_ahead=3: OK
#   - SHURWID n_ahead=7: OK
# [369/464] Training SHYAMPSUG ...
#   - SHYAMPSUG n_ahead=1: OK
#   - SHYAMPSUG n_ahead=3: OK
#   - SHYAMPSUG n_ahead=7: OK
# [370/464] Training SIBL ...
#   - SIBL n_ahead=1: OK
#   - SIBL n_ahead=3: OK
#   - SIBL n_ahead=7: OK
# [371/464] Training SICL ...
#   - SICL n_ahead=1: OK
#   - SICL n_ahead=3: OK
#   - SICL n_ahead=7: OK
# [372/464] Training SILCOPHL ...
#   - SILCOPHL n_ahead=1: OK
#   - SILCOPHL n_ahead=3: OK
#   - SILCOPHL n_ahead=7: OK
# [373/464] Training SILVAPHL ...
#   - SILVAPHL n_ahead=1: OK
#   - SILVAPHL n_ahead=3: OK
#   - SILVAPHL n_ahead=7: OK
# [374/464] Training SIMTEX ...
#   - SIMTEX n_ahead=1: OK
#   - SIMTEX n_ahead=3: OK
#   - SIMTEX n_ahead=7: OK
# [375/464] Training SINGERBD ...
#   - SINGERBD n_ahead=1: OK
#   - SINGERBD n_ahead=3: OK
#   - SINGERBD n_ahead=7: OK
# [376/464] Training SINOBANGLA ...
#   - SINOBANGLA n_ahead=1: OK
#   - SINOBANGLA n_ahead=3: OK
#   - SINOBANGLA n_ahead=7: OK
# [377/464] Training SIPLC ...
#   - SIPLC n_ahead=1: OK
#   - SIPLC n_ahead=3: OK
#   - SIPLC n_ahead=7: OK
# [378/464] Training SKTRIMS ...
#   - SKTRIMS n_ahead=1: OK
#   - SKTRIMS n_ahead=3: OK
#   - SKTRIMS n_ahead=7: OK
# [379/464] Training SONALIANSH ...
#   - SONALIANSH n_ahead=1: OK
#   - SONALIANSH n_ahead=3: OK
#   - SONALIANSH n_ahead=7: OK
# [380/464] Training SONALILIFE ...
#   - SONALILIFE n_ahead=1: OK
#   - SONALILIFE n_ahead=3: OK
#   - SONALILIFE n_ahead=7: OK
# [381/464] Training SONALIPAPR ...
#   - SONALIPAPR n_ahead=1: OK
#   - SONALIPAPR n_ahead=3: OK
#   - SONALIPAPR n_ahead=7: OK
# [382/464] Training SONARBAINS ...
#   - SONARBAINS n_ahead=1: OK
#   - SONARBAINS n_ahead=3: OK
#   - SONARBAINS n_ahead=7: OK
# [383/464] Training SONARGAON ...
#   - SONARGAON n_ahead=1: OK
#   - SONARGAON n_ahead=3: OK
#   - SONARGAON n_ahead=7: OK
# [384/464] Training SOUTHEASTB ...
#   - SOUTHEASTB n_ahead=1: OK
#   - SOUTHEASTB n_ahead=3: OK
#   - SOUTHEASTB n_ahead=7: OK
# [385/464] Training SPCERAMICS ...
#   - SPCERAMICS n_ahead=1: OK
#   - SPCERAMICS n_ahead=3: OK
#   - SPCERAMICS n_ahead=7: OK
# [386/464] Training SPCL ...
#   - SPCL n_ahead=1: OK
#   - SPCL n_ahead=3: OK
#   - SPCL n_ahead=7: OK
# [387/464] Training SQUARETEXT ...
#   - SQUARETEXT n_ahead=1: OK
#   - SQUARETEXT n_ahead=3: OK
#   - SQUARETEXT n_ahead=7: OK
# [388/464] Training SQURPHARMA ...
#   - SQURPHARMA n_ahead=1: OK
#   - SQURPHARMA n_ahead=3: OK
#   - SQURPHARMA n_ahead=7: OK
# [389/464] Training SSSTEEL ...
#   - SSSTEEL n_ahead=1: OK
#   - SSSTEEL n_ahead=3: OK
#   - SSSTEEL n_ahead=7: OK
# [390/464] Training STANCERAM ...
#   - STANCERAM n_ahead=1: OK
#   - STANCERAM n_ahead=3: OK
#   - STANCERAM n_ahead=7: OK
# [391/464] Training STANDARINS ...
#   - STANDARINS n_ahead=1: OK
#   - STANDARINS n_ahead=3: OK
#   - STANDARINS n_ahead=7: OK
# [392/464] Training STANDBANKL ...
#   - STANDBANKL n_ahead=1: OK
#   - STANDBANKL n_ahead=3: OK
#   - STANDBANKL n_ahead=7: OK
# [393/464] Training STYLECRAFT ...
#   - STYLECRAFT n_ahead=1: OK
#   - STYLECRAFT n_ahead=3: OK
#   - STYLECRAFT n_ahead=7: OK
# [394/464] Training SUMITPOWER ...
#   - SUMITPOWER n_ahead=1: OK
#   - SUMITPOWER n_ahead=3: OK
#   - SUMITPOWER n_ahead=7: OK
# [395/464] Training SUNLIFEINS ...
#   - SUNLIFEINS n_ahead=1: OK
#   - SUNLIFEINS n_ahead=3: OK
#   - SUNLIFEINS n_ahead=7: OK
# [396/464] Training TAKAFULINS ...
#   - TAKAFULINS n_ahead=1: OK
#   - TAKAFULINS n_ahead=3: OK
#   - TAKAFULINS n_ahead=7: OK
# [397/464] Training TALLUSPIN ...
#   - TALLUSPIN n_ahead=1: OK
#   - TALLUSPIN n_ahead=3: OK
#   - TALLUSPIN n_ahead=7: OK
# [398/464] Training TAMIJTEX ...
#   - TAMIJTEX n_ahead=1: OK
#   - TAMIJTEX n_ahead=3: OK
#   - TAMIJTEX n_ahead=7: OK
# [399/464] Training TB10Y0135 ...
#   - TB10Y0135 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB10Y0135 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB10Y0135 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [400/464] Training TB10Y0234 ...
#   - TB10Y0234 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB10Y0234 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB10Y0234 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [401/464] Training TB10Y0434 ...
#   - TB10Y0434 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB10Y0434 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB10Y0434 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [402/464] Training TB10Y0634 ...
#   - TB10Y0634 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB10Y0634 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB10Y0634 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [403/464] Training TB10Y0932 ...
#   - TB10Y0932 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB10Y0932 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB10Y0932 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [404/464] Training TB15Y0339 ...
#   - TB15Y0339 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB15Y0339 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB15Y0339 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [405/464] Training TB15Y0637 ...
#   - TB15Y0637 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB15Y0637 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB15Y0637 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [406/464] Training TB15Y0925 ...
#   - TB15Y0925 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB15Y0925 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB15Y0925 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [407/464] Training TB20Y0143 ...
#   - TB20Y0143 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB20Y0143 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB20Y0143 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [408/464] Training TB20Y0744 ...
#   - TB20Y0744 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB20Y0744 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB20Y0744 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [409/464] Training TB20Y1242 ...
#   - TB20Y1242 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB20Y1242 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB20Y1242 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [410/464] Training TB2Y0126 ...
#   - TB2Y0126 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB2Y0126 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB2Y0126 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [411/464] Training TB2Y0227 ...
#   - TB2Y0227 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB2Y0227 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB2Y0227 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [412/464] Skipping TB2Y0325: not enough rows (6).
# [413/464] Training TB2Y0426 ...
#   - TB2Y0426 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB2Y0426 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB2Y0426 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [414/464] Skipping TB2Y0525: not enough rows (40).
# [415/464] Training TB2Y0526 ...
#   - TB2Y0526 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB2Y0526 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB2Y0526 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [416/464] Training TB2Y0626 ...
#   - TB2Y0626 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB2Y0626 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB2Y0626 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [417/464] Training TB2Y0725 ...
#   - TB2Y0725 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB2Y0725 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB2Y0725 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [418/464] Training TB2Y0826 ...
#   - TB2Y0826 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB2Y0826 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB2Y0826 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [419/464] Training TB2Y0925 ...
#   - TB2Y0925 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB2Y0925 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB2Y0925 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [420/464] Training TB2Y1026 ...
#   - TB2Y1026 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB2Y1026 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB2Y1026 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [421/464] Training TB2Y1125 ...
#   - TB2Y1125 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB2Y1125 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB2Y1125 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [422/464] Training TB2Y1126 ...
#   - TB2Y1126 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB2Y1126 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB2Y1126 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [423/464] Skipping TB5Y0125: not enough rows (12).
# [424/464] Training TB5Y0230 ...
#   - TB5Y0230 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB5Y0230 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB5Y0230 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [425/464] Skipping TB5Y0425: not enough rows (43).
# [426/464] Training TB5Y0429 ...
#   - TB5Y0429 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB5Y0429 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB5Y0429 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [427/464] Training TB5Y0529 ...
#   - TB5Y0529 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB5Y0529 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB5Y0529 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [428/464] Training TB5Y1029 ...
#   - TB5Y1029 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB5Y1029 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB5Y1029 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [429/464] Training TB5Y1128 ...
#   - TB5Y1128 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB5Y1128 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB5Y1128 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [430/464] Training TB5Y1225 ...
#   - TB5Y1225 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB5Y1225 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB5Y1225 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [431/464] Training TB5Y1229 ...
#   - TB5Y1229 n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TB5Y1229 n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TB5Y1229 n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [432/464] Training TECHNODRUG ...
#   - TECHNODRUG n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - TECHNODRUG n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - TECHNODRUG n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [433/464] Training TILIL ...
#   - TILIL n_ahead=1: OK
#   - TILIL n_ahead=3: OK
#   - TILIL n_ahead=7: OK
# [434/464] Training TITASGAS ...
#   - TITASGAS n_ahead=1: OK
#   - TITASGAS n_ahead=3: OK
#   - TITASGAS n_ahead=7: OK
# [435/464] Training TOSRIFA ...
#   - TOSRIFA n_ahead=1: OK
#   - TOSRIFA n_ahead=3: OK
#   - TOSRIFA n_ahead=7: OK
# [436/464] Training TRUSTB1MF ...
#   - TRUSTB1MF n_ahead=1: OK
#   - TRUSTB1MF n_ahead=3: OK
#   - TRUSTB1MF n_ahead=7: OK
# [437/464] Training TRUSTBANK ...
#   - TRUSTBANK n_ahead=1: OK
#   - TRUSTBANK n_ahead=3: OK
#   - TRUSTBANK n_ahead=7: OK
# [438/464] Training TUNGHAI ...
#   - TUNGHAI n_ahead=1: OK
#   - TUNGHAI n_ahead=3: OK
#   - TUNGHAI n_ahead=7: OK
# [439/464] Training UCB ...
#   - UCB n_ahead=1: OK
#   - UCB n_ahead=3: OK
#   - UCB n_ahead=7: OK
# [440/464] Training UCB2PBOND ...
#   - UCB2PBOND n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - UCB2PBOND n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - UCB2PBOND n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [441/464] Training UNILEVERCL ...
#   - UNILEVERCL n_ahead=1: OK
#   - UNILEVERCL n_ahead=3: OK
#   - UNILEVERCL n_ahead=7: OK
# [442/464] Training UNIONBANK ...
#   - UNIONBANK n_ahead=1: OK
#   - UNIONBANK n_ahead=3: OK
#   - UNIONBANK n_ahead=7: OK
# [443/464] Training UNIONCAP ...
#   - UNIONCAP n_ahead=1: OK
#   - UNIONCAP n_ahead=3: OK
#   - UNIONCAP n_ahead=7: OK
# [444/464] Training UNIONINS ...
#   - UNIONINS n_ahead=1: OK
#   - UNIONINS n_ahead=3: OK
#   - UNIONINS n_ahead=7: OK
# [445/464] Training UNIQUEHRL ...
#   - UNIQUEHRL n_ahead=1: OK
#   - UNIQUEHRL n_ahead=3: OK
#   - UNIQUEHRL n_ahead=7: OK
# [446/464] Training UNITEDFIN ...
#   - UNITEDFIN n_ahead=1: OK
#   - UNITEDFIN n_ahead=3: OK
#   - UNITEDFIN n_ahead=7: OK
# [447/464] Training UNITEDINS ...
#   - UNITEDINS n_ahead=1: OK
#   - UNITEDINS n_ahead=3: OK
#   - UNITEDINS n_ahead=7: OK
# [448/464] Training UPGDCL ...
#   - UPGDCL n_ahead=1: OK
#   - UPGDCL n_ahead=3: OK
#   - UPGDCL n_ahead=7: OK
# [449/464] Training USMANIAGL ...
#   - USMANIAGL n_ahead=1: OK
#   - USMANIAGL n_ahead=3: OK
#   - USMANIAGL n_ahead=7: OK
# [450/464] Training UTTARABANK ...
#   - UTTARABANK n_ahead=1: OK
#   - UTTARABANK n_ahead=3: OK
#   - UTTARABANK n_ahead=7: OK
# [451/464] Training UTTARAFIN ...
#   - UTTARAFIN n_ahead=1: OK
#   - UTTARAFIN n_ahead=3: OK
#   - UTTARAFIN n_ahead=7: OK
# [452/464] Training VAMLBDMF1 ...
#   - VAMLBDMF1 n_ahead=1: OK
#   - VAMLBDMF1 n_ahead=3: OK
#   - VAMLBDMF1 n_ahead=7: OK
# [453/464] Training VAMLRBBF ...
#   - VAMLRBBF n_ahead=1: OK
#   - VAMLRBBF n_ahead=3: OK
#   - VAMLRBBF n_ahead=7: OK
# [454/464] Training VFSTDL ...
#   - VFSTDL n_ahead=1: OK
#   - VFSTDL n_ahead=3: OK
#   - VFSTDL n_ahead=7: OK
# [455/464] Training WALTONHIL ...
#   - WALTONHIL n_ahead=1: OK
#   - WALTONHIL n_ahead=3: OK
#   - WALTONHIL n_ahead=7: OK
# [456/464] Training WATACHEM ...
#   - WATACHEM n_ahead=1: OK
#   - WATACHEM n_ahead=3: OK
#   - WATACHEM n_ahead=7: OK
# [457/464] Training WEBCOATS ...
#   - WEBCOATS n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - WEBCOATS n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - WEBCOATS n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [458/464] Training WMSHIPYARD ...
#   - WMSHIPYARD n_ahead=1: OK
#   - WMSHIPYARD n_ahead=3: OK
#   - WMSHIPYARD n_ahead=7: OK
# [459/464] Training WONDERTOYS ...
#   - WONDERTOYS n_ahead=1: OK
#   - WONDERTOYS n_ahead=3: OK
#   - WONDERTOYS n_ahead=7: OK
# [460/464] Training YPL ...
#   - YPL n_ahead=1: OK
#   - YPL n_ahead=3: OK
#   - YPL n_ahead=7: OK
# [461/464] Training YUSUFLOUR ...
#   - YUSUFLOUR n_ahead=1: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=1).
#   - YUSUFLOUR n_ahead=3: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=3).
#   - YUSUFLOUR n_ahead=7: Not enough data after windowing (SEQ_LEN=60, N_AHEAD=7).
# [462/464] Training ZAHEENSPIN ...
#   - ZAHEENSPIN n_ahead=1: OK
#   - ZAHEENSPIN n_ahead=3: OK
#   - ZAHEENSPIN n_ahead=7: OK
# [463/464] Training ZAHINTEX ...
#   - ZAHINTEX n_ahead=1: OK
#   - ZAHINTEX n_ahead=3: OK
#   - ZAHINTEX n_ahead=7: OK
# [464/464] Training ZEALBANGLA ...
#   - ZEALBANGLA n_ahead=1: OK
#   - ZEALBANGLA n_ahead=3: OK
#   - ZEALBANGLA n_ahead=7: OK
# Saved summary to: ./artifacts/metrics/training_summary.csv
#            scrip  n_ahead   status  \
# 1370   YUSUFLOUR        7  skipped
# 1371  ZAHEENSPIN        1       ok
# 1372  ZAHEENSPIN        3       ok
# 1373  ZAHEENSPIN        7       ok
# 1374    ZAHINTEX        1       ok
# 1375    ZAHINTEX        3       ok
# 1376    ZAHINTEX        7       ok
# 1377  ZEALBANGLA        1       ok
# 1378  ZEALBANGLA        3       ok
# 1379  ZEALBANGLA        7       ok
#
#                                              model_path  \
# 1370                                               None
# 1371  ./artifacts/models/ZAHEENSPIN/lstm_ZAHEENSPIN_...
# 1372  ./artifacts/models/ZAHEENSPIN/lstm_ZAHEENSPIN_...
# 1373  ./artifacts/models/ZAHEENSPIN/lstm_ZAHEENSPIN_...
# 1374  ./artifacts/models/ZAHINTEX/lstm_ZAHINTEX_seq6...
# 1375  ./artifacts/models/ZAHINTEX/lstm_ZAHINTEX_seq6...
# 1376  ./artifacts/models/ZAHINTEX/lstm_ZAHINTEX_seq6...
# 1377  ./artifacts/models/ZEALBANGLA/lstm_ZEALBANGLA_...
# 1378  ./artifacts/models/ZEALBANGLA/lstm_ZEALBANGLA_...
# 1379  ./artifacts/models/ZEALBANGLA/lstm_ZEALBANGLA_...
#
#                                             scaler_path  rmse_mean  mape_mean
# 1370                                               None        NaN        NaN
# 1371  ./artifacts/models/ZAHEENSPIN/scaler_ZAHEENSPI...   0.470521   4.851537
# 1372  ./artifacts/models/ZAHEENSPIN/scaler_ZAHEENSPI...   0.501619   5.271421
# 1373  ./artifacts/models/ZAHEENSPIN/scaler_ZAHEENSPI...   0.539848   5.753381
# 1374    ./artifacts/models/ZAHINTEX/scaler_ZAHINTEX.bin   0.308946   3.462018
# 1375    ./artifacts/models/ZAHINTEX/scaler_ZAHINTEX.bin   0.336585   3.853216
# 1376    ./artifacts/models/ZAHINTEX/scaler_ZAHINTEX.bin   0.380431   4.483624
# 1377  ./artifacts/models/ZEALBANGLA/scaler_ZEALBANGL...   7.180487   4.669894
# 1378  ./artifacts/models/ZEALBANGLA/scaler_ZEALBANGL...   7.682361   4.265397
# 1379  ./artifacts/models/ZEALBANGLA/scaler_ZEALBANGL...  20.171880  11.249414

# %% [markdown]
# ## 7) How to Load a Trained Model Later (Example)
#
# This shows how your **website/backend** can load a specific Scrip + horizon,
# scale the last 60 days, and predict the next *n* days.

# %%
# Example: replace with an actual scrip from your data
EXAMPLE_SCRIP = "ACI"  # e.g., "ACI"

if EXAMPLE_SCRIP is not None:
    scrip_dir = os.path.join(MODELS_DIR, EXAMPLE_SCRIP)
    # Choose horizon
    n_ahead = 7
    model_path = os.path.join(scrip_dir, f"lstm_{EXAMPLE_SCRIP}_seq{SEQ_LEN}_nahead{n_ahead}.keras")
    scaler_path = os.path.join(scrip_dir, f"scaler_{EXAMPLE_SCRIP}.bin")

    model = keras.models.load_model(model_path)
    scaler = joblib.load(scaler_path)

    # Prepare the last window from the CSV (same flow as training)
    scrip_df = df_all[df_all[SCRIP_COLUMN] == EXAMPLE_SCRIP].sort_values(DATE_COLUMN).reset_index(drop=True)
    scaled = scaler.transform(scrip_df[FEATURE_COLS].values)
    last_window = scaled[-SEQ_LEN:].reshape(1, SEQ_LEN, scaled.shape[1])
    pred_scaled = model.predict(last_window, verbose=0).ravel()
    pred = scaler.inverse_transform(pred_scaled.reshape(-1, 1)).ravel()

    print(f"Next {n_ahead} predictions for {EXAMPLE_SCRIP}:", pred)
else:
    print("Set EXAMPLE_SCRIP to test loading & predicting.")
# Out:
# Next 7 predictions for ACI: [189.85164 192.29855 204.5495  192.19714 193.1397  196.11758 188.37393]

# %% [markdown]
# ---
#
# ### Tips
# - If you want **multivariate** input (e.g., `['Open','High','Low','Close','Volume']`), set `FEATURE_COLS` accordingly.
#   - The **first** entry in `FEATURE_COLS` is treated as the target for inverse scaling (keep `Close` first).
# - Consider **walk-forward validation** for more robust evaluation.
# - For deployment at scale, consider exporting to **SavedModel** and serving via TensorFlow Serving.
#
# ### Done!
